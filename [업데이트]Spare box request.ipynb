# %%
from tool import *

# %%
with open('D:/Data/TCL box.bin', 'rb') as f:
    box = pickle.load(f)

# %% [markdown]
# ## 1. 신규 박스 요청 정보 추가

# %%
new_request = pd.read_clipboard()
new_request
# Out:
#   Request Date To Site Mapping Model.Suffix  QTY
# 0   2024-03-11    ENCI       27MR41S-B.ACCQ   20

# %%
box = pd.concat([box, new_request]).reset_index(drop=True)

# %%
box
# Out:
#    Request Date To Site Mapping Model.Suffix  QTY  \
# 0    2023-11-14    ENCI       22MR410-B.AUSQ   20
# 1    2023-11-08    EATH       22MR410-B.ATMQ   40
# 2    2023-11-08    EATH       27MR400-B.ATMQ   20
# 3    2023-11-08    EASL       27MR400-B.AHKQ   10
# 4    2023-11-20  ENUS_V       27MR400-B.AUSQ    2
# 5    2023-12-18    EKHQ         22MR410.AKRQ   20
# 6    2023-12-18    EKHQ         27MR400.AKRQ   20
# 7    2024-01-11    EACM       22MR410-B.APHQ   22
# 8    2024-01-11    EACM       24MR400-B.APHQ   30
# 9    2024-02-13    ENCI       27MR41S-B.ACCQ   15
# 10   2024-02-26    EACM       24MR400-B.APHQ   74
# 11   2024-02-28    EACM       22MR410-B.APHQ    7
# 12   2024-02-28    EACM       24MR400-B.APHQ   30
# 13   2024-03-11    ENCI       27MR41S-B.ACCQ   20
#
#                   Shipment Schedule    B/L Number Container Number
# 0   Ship with 11/27W shipping batch  PLISZ4E13545      MRKU8876626
# 1   Ship with 11/27W shipping batch  PLISZ4E13560      FBIU0292678
# 2   Ship with 11/27W shipping batch  PLISZ4E13560      FBIU0292678
# 3   Ship with 11/27W shipping batch  PLISZ4E13682      FCIU6360956
# 4    Ship with 1/15W shipping batch  PLISZ4F00772      MRKU2519257
# 5     Ship with 1/8W shipping batch  PLISZ4F00301      NSSU7147311
# 6     Ship with 1/8W shipping batch  PLISZ4F00301      NSSU7147311
# 7     Ship with 2/5W shipping batch  PLISZ4F01838      TCNU2265935
# 8     Ship with 2/5W shipping batch  PLISZ4F01838      TCNU2265935
# 9                               NaN           NaN              NaN
# 10                              NaN           NaN              NaN
# 11                              NaN           NaN              NaN
# 12                              NaN           NaN              NaN
# 13                              NaN           NaN              NaN

# %%
# DB 저장
with open('D:/Data/TCL box.bin', 'wb') as f:
    pickle.dump(box, f)

# %% [markdown]
# ## 2. 박스 요청 건에 대한 공급 일정 업데이트

# %%
with open('D:/Data/TCL box.bin', 'rb') as f:
    box = pickle.load(f)

# %%
box
# Out:
#   Request Date To Site Mapping Model.Suffix  QTY  \
# 0   2023-11-14    ENCI       22MR410-B.AUSQ   20
# 1   2023-11-08    EATH       22MR410-B.ATMQ   40
# 2   2023-11-08    EATH       27MR400-B.ATMQ   20
# 3   2023-11-08    EASL       27MR400-B.AHKQ   10
# 4   2023-11-20  ENUS_V       27MR400-B.AUSQ    2
# 5   2023-12-18    EKHQ         22MR410.AKRQ   20
# 6   2023-12-18    EKHQ         27MR400.AKRQ   20
# 7   2024-01-11    EACM       22MR410-B.APHQ   22
# 8   2024-01-11    EACM       24MR400-B.APHQ   30
#
#                  Shipment Schedule    B/L Number Container Number
# 0  Ship with 11/27W shipping batch  PLISZ4E13545      MRKU8876626
# 1  Ship with 11/27W shipping batch  PLISZ4E13560      FBIU0292678
# 2  Ship with 11/27W shipping batch  PLISZ4E13560      FBIU0292678
# 3  Ship with 11/27W shipping batch  PLISZ4E13682      FCIU6360956
# 4   Ship with 1/15W shipping batch  PLISZ4F00772      MRKU2519257
# 5    Ship with 1/8W shipping batch  PLISZ4F00301      NSSU7147311
# 6    Ship with 1/8W shipping batch  PLISZ4F00301      NSSU7147311
# 7    Ship with 2/5W shipping batch           NaN              NaN
# 8    Ship with 2/5W shipping batch           NaN              NaN

# %%
updated_schedule = pd.read_clipboard() # 엑셀에서 업데이트한 내용을 복사해서 clipboard에서 읽어옴
updated_schedule
# Out:
#   Request Date To Site Mapping Model.Suffix  QTY  \
# 0   2024-01-11    EACM       22MR410-B.APHQ   22
# 1   2024-01-11    EACM       24MR400-B.APHQ   30
#
#                Shipment Schedule    B/L Number Container Number
# 0  Ship with 2/5W shipping batch  PLISZ4F01838      TCNU2265935
# 1  Ship with 2/5W shipping batch  PLISZ4F01838      TCNU2265935

# %%
updated_schedule = updated_schedule.set_index(['Request Date', 'To Site', 'Mapping Model.Suffix', 'QTY'])

# %%
box = box.set_index(['Request Date', 'To Site', 'Mapping Model.Suffix', 'QTY'])

# %%
box.update(updated_schedule)

# %%
box
# Out:
#                                                              Shipment Schedule  \
# Request Date To Site Mapping Model.Suffix QTY
# 2023-11-14   ENCI    22MR410-B.AUSQ       20   Ship with 11/27W shipping batch
# 2023-11-08   EATH    22MR410-B.ATMQ       40   Ship with 11/27W shipping batch
#                      27MR400-B.ATMQ       20   Ship with 11/27W shipping batch
#              EASL    27MR400-B.AHKQ       10   Ship with 11/27W shipping batch
# 2023-11-20   ENUS_V  27MR400-B.AUSQ       2     Ship with 1/15W shipping batch
# 2023-12-18   EKHQ    22MR410.AKRQ         20     Ship with 1/8W shipping batch
#                      27MR400.AKRQ         20     Ship with 1/8W shipping batch
# 2024-01-11   EACM    22MR410-B.APHQ       22     Ship with 2/5W shipping batch
#                      24MR400-B.APHQ       30     Ship with 2/5W shipping batch
#
#                                                  B/L Number Container Number
# Request Date To Site Mapping Model.Suffix QTY
# 2023-11-14   ENCI    22MR410-B.AUSQ       20   PLISZ4E13545      MRKU8876626
# 2023-11-08   EATH    22MR410-B.ATMQ       40   PLISZ4E13560      FBIU0292678
#                      27MR400-B.ATMQ       20   PLISZ4E13560      FBIU0292678
#              EASL    27MR400-B.AHKQ       10   PLISZ4E13682      FCIU6360956
# 2023-11-20   ENUS_V  27MR400-B.AUSQ       2    PLISZ4F00772      MRKU2519257
# 2023-12-18   EKHQ    22MR410.AKRQ         20   PLISZ4F00301      NSSU7147311
#                      27MR400.AKRQ         20   PLISZ4F00301      NSSU7147311
# 2024-01-11   EACM    22MR410-B.APHQ       22   PLISZ4F01838      TCNU2265935
#                      24MR400-B.APHQ       30   PLISZ4F01838      TCNU2265935

# %%
box = box.reset_index()

# %%
# DB 저장
with open('D:/Data/TCL box.bin', 'wb') as f:
    pickle.dump(box, f)
