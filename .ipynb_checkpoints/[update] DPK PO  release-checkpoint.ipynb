# %%
from tool import *

# %%
get_DPK_stock()
# Out:
# DPK stock calculation based on latest Input Plan(2023-01-20)
#                                        OS TYPE     MS P/N   Stock  \
# 1                      WINDOWS 11 HOME (64BIT)  KW9-00609  7327.0
# 2         WINDOWS 11 HOME FOR ADVANCED (64BIT)  KUK-00003    76.0
# 3     WINDOWS 11 HOME FOR PLUS DEVICES (64BIT)  KK3-00027  3717.0
# 4                       WINDOWS 11 PRO (64BIT)  FQC-10428  1815.0
# 5                         WINDOWS 11 PRO ENTRY  CSQ-00009    50.0
# 6             WINDOWS 11 PRO WITH Downgrade FR  KR5-00007  1660.0
# 7  WINDOWS 11 HOME FOR PLUS DEVICES (SL_64BIT)  NA3-00013    20.0
#
#    Order Qty_on_23-01-18  2023-01-09(W02)  2023-01-16(W03)  2023-01-23(W04)  \
# 1                 4200.0             3570             1622             1449
# 2                  140.0               45                0                0
# 3                 5000.0              360              435              230
# 4                 2400.0               45              175             1000
# 5                    NaN               46                0                0
# 6                    NaN               68               50             1152
# 7                    NaN                0                0                0
#
#    2023-01-30(W05)  Stock_End
# 1             1191     3695.0
# 2              160       11.0
# 3              745     6947.0
# 4              540     2455.0
# 5                0        4.0
# 6              240      150.0
# 7                0       20.0

# %% [markdown]
# ## DPK blanket PO 발행 결과 열기

# %%
df = pd.read_clipboard()
df
# Out:
#                  Component  Stock  WK04                Unnamed: 3
# 0  AZDPKW11161*SAE30762501   3181  5000          Win 11 Home Plus
# 1  AZDPKW11196*SAE30761301   2882  4200   Win 11 Home OEM OLC OA3
# 2  AZDPKW11197*SAE30761501   1770  1200    Win 11 Pro OEM OLC OA3
# 3  AZDPKW11198*SAE30762701     31   140  Windows 11 Home Advanced

# %%
df
# Out:
#    Stock  Request Qty                Unnamed: 3   Quanta P/N       LG P/N  \
# 0   3181         5000          Win 11 Home Plus  AZDPKW11161  SAE30762501
# 1   2882         4200   Win 11 Home OEM OLC OA3  AZDPKW11196  SAE30761301
# 2   1770         1200    Win 11 Pro OEM OLC OA3  AZDPKW11197  SAE30761501
# 3     31          140  Windows 11 Home Advanced  AZDPKW11198  SAE30762701
#
#   Quanta Request Date
# 0          2023-01-18
# 1          2023-01-18
# 2          2023-01-18
# 3          2023-01-18

# %%
get_DPK_stock()
# Out:
# Reference Data of Input Plan : 2023-01-17
#                                        OS TYPE   Stock  2023-01-09(W02)  \
# 0                      WINDOWS 11 HOME (64BIT)  7327.0             3570
# 1         WINDOWS 11 HOME FOR ADVANCED (64BIT)    76.0               45
# 2     WINDOWS 11 HOME FOR PLUS DEVICES (64BIT)  3717.0              360
# 3                       WINDOWS 11 PRO (64BIT)  1815.0               45
# 4                         WINDOWS 11 PRO ENTRY    50.0               46
# 5             WINDOWS 11 PRO WITH Downgrade FR  1660.0               68
# 6  WINDOWS 11 HOME FOR PLUS DEVICES (SL_64BIT)    20.0                0
#
#    2023-01-16(W03)  2023-01-23(W04)  2023-01-30(W05)  Stock_end
# 0             2262              809             1191     -505.0
# 1                0                0               90      -59.0
# 2              385               50              965     1957.0
# 3                5              270             1400       95.0
# 4                0                0                0        4.0
# 5               50                0             1392      150.0
# 6                0                0                0       20.0

# %%
df['Quanta P/N'] = df['Component'].apply(lambda x:x.split('*')[0])
df['LG P/N'] = df['Component'].apply(lambda x:x.split('*')[1])
df['Quanta Request Date'] = datetime.date(2023, 1, 18)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Python\Python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# C:\Python\Python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\Python\Python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Component'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1124/2517122921.py in <module>
# ----> 1 df['Quanta P/N'] = df['Component'].apply(lambda x:x.split('*')[0])
#       2 df['LG P/N'] = df['Component'].apply(lambda x:x.split('*')[1])
#       3 df['Quanta Request Date'] = datetime.date(2023, 1, 18)
#       4 df
#
# C:\Python\Python39\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3453             if self.columns.nlevels > 1:
#    3454                 return self._getitem_multilevel(key)
# -> 3455             indexer = self.columns.get_loc(key)
#    3456             if is_integer(indexer):
#    3457                 indexer = [indexer]
#
# C:\Python\Python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Component'

# %%
df = df.drop(columns='Component')

# %%
df = df.rename(columns={'WK04':'Request Qty'})

# %%
with open('D:/Data/DB backup/dpk.bin', 'rb') as f:
    dpk = pickle.load(f)

# %%
df.merge(dpk)
# Out:
#    Stock  Request Qty                Unnamed: 3   Quanta P/N       LG P/N  \
# 0   3181         5000          Win 11 Home Plus  AZDPKW11161  SAE30762501
# 1   2882         4200   Win 11 Home OEM OLC OA3  AZDPKW11196  SAE30761301
# 2   1770         1200    Win 11 Pro OEM OLC OA3  AZDPKW11197  SAE30761501
# 3     31          140  Windows 11 Home Advanced  AZDPKW11198  SAE30762701
#
#   Quanta Request Date     MS P/N                         Part Name
# 0          2023-01-05  KK3-00027                  Win 11 Home Plus
# 1          2023-01-05  KW9-00609           Win 11 Home OEM OLC OA3
# 2          2023-01-05  FQC-10428            Win 11 Pro OEM OLC OA3
# 3          2023-01-05  KUK-00003  Win 11 Home Advanced OEM OLC OA3

# %%
with open('D:/Data/DPK blanket PO DB.bin', 'rb') as f:
    bpo = pickle.load(f)

# %%
bpo = pd.concat([bpo, df.merge(dpk)])[bpo.columns]
bpo
# Out:
#     Stock  Request Qty   Quanta P/N       LG P/N  Quanta Request Date  \
# 0     916         1000  AZDPKW10068  SAE30320201  2022-10-10 00:00:00
# 1     820         1200  AZDPKW11196  SAE30761301  2022-10-10 00:00:00
# 2     619          300  AZDPKW11197  SAE30761501  2022-10-10 00:00:00
# 3      45           50  AZDPKW11300  SAE30762601  2022-10-10 00:00:00
# 4    1427         1300  AZDPKW11161  SAE30762501  2022-10-25 00:00:00
# 5    1180         2000  AZDPKW11196  SAE30761301  2022-10-25 00:00:00
# 6     473          700  AZDPKW11197  SAE30761501  2022-10-25 00:00:00
# 7      56          200  AZDPKW11198  SAE30762701  2022-10-25 00:00:00
# 8       0          300  AZDPKW11297  SAE30761601  2022-10-25 00:00:00
# 9    1113          500  AZDPKW11197  SAE30761501  2022-10-31 00:00:00
# 10    784          200  AZDPKW11197  SAE30761501  2022-11-09 00:00:00
# 11   1212          300  AZDPKW11161  SAE30762501  2022-11-21 00:00:00
# 12   1213         1000  AZDPKW11196  SAE30761301  2022-11-21 00:00:00
# 13    392          600  AZDPKW11197  SAE30761501  2022-11-21 00:00:00
# 14    524         1600  AZDPKW11161  SAE30762501  2022-12-05 00:00:00
# 15    976         2300  AZDPKW11196  SAE30761301  2022-12-05 00:00:00
# 16    913         1200  AZDPKW11197  SAE30761501  2022-12-05 00:00:00
# 17    718         1200  AZDPKW11297  SAE30761601  2022-12-05 00:00:00
# 18      0           50  AZDPKW11303  SAE30761801  2022-12-05 00:00:00
# 19   1709          300  AZDPKW11161  SAE30762501  2022-12-20 00:00:00
# 20   2361         5300  AZDPKW11196  SAE30761301  2022-12-20 00:00:00
# 21    947         1600  AZDPKW11197  SAE30761501  2022-12-20 00:00:00
# 22     96           60  AZDPKW11198  SAE30762701  2022-12-20 00:00:00
# 23   1309          650  AZDPKW11297  SAE30761601  2022-12-20 00:00:00
# 24   1217         2500  AZDPKW11161  SAE30762501  2023-01-05 00:00:00
# 25   7127          200  AZDPKW11196  SAE30761301  2023-01-05 00:00:00
# 26   3181         5000  AZDPKW11161  SAE30762501           2023-01-05
# 27   2882         4200  AZDPKW11196  SAE30761301           2023-01-05
# 28   1770         1200  AZDPKW11197  SAE30761501           2023-01-05
# 29     31          140  AZDPKW11198  SAE30762701           2023-01-05
# 0    3181         5000  AZDPKW11161  SAE30762501           2023-01-18
# 1    2882         4200  AZDPKW11196  SAE30761301           2023-01-18
# 2    1770         1200  AZDPKW11197  SAE30761501           2023-01-18
# 3      31          140  AZDPKW11198  SAE30762701           2023-01-18
#
#        MS P/N                         Part Name     Order Type      LG PO No.  \
# 0   FQC-08797                    Windows 10 Pro  Blanket Order  O202200028543
# 1   KW9-00609           Win 11 Home OEM OLC OA3  Blanket Order  O202200028505
# 2   FQC-10428            Win 11 Pro OEM OLC OA3  Blanket Order  O202200028504
# 3   NA3-00013               Win 11 Home Plus SL  Blanket Order  O202200028503
# 4   KK3-00027                  Win 11 Home Plus  Blanket Order  O202200028607
# 5   KW9-00609           Win 11 Home OEM OLC OA3  Blanket Order  O202200028606
# 6   FQC-10428            Win 11 Pro OEM OLC OA3  Blanket Order  O202200028605
# 7   KUK-00003  Win 11 Home Advanced OEM OLC OA3  Blanket Order  O202200028604
# 8   KR5-00007  Windows 11 Pro with Downgrade FR  Blanket Order  O202200028603
# 9   FQC-10428            Win 11 Pro OEM OLC OA3  Blanket Order  O202200028623
# 10  FQC-10428            Win 11 Pro OEM OLC OA3  Blanket Order  O202200028733
# 11  KK3-00027                  Win 11 Home Plus  Blanket Order  O202200029097
# 12  KW9-00609           Win 11 Home OEM OLC OA3  Blanket Order  O202200028834
# 13  FQC-10428            Win 11 Pro OEM OLC OA3  Blanket Order  O202200028833
# 14  KK3-00027                  Win 11 Home Plus  Blanket Order  O202200028957
# 15  KW9-00609           Win 11 Home OEM OLC OA3  Blanket Order  O202200028956
# 16  FQC-10428            Win 11 Pro OEM OLC OA3  Blanket Order  O202200028955
# 17  KR5-00007  Windows 11 Pro with Downgrade FR  Blanket Order  O202200028954
# 18  CSQ-00009              Windows 11 Pro Entry  Blanket Order  O202200028953
# 19  KK3-00027                  Win 11 Home Plus  Blanket Order  O202200029097
# 20  KW9-00609           Win 11 Home OEM OLC OA3  Blanket Order  O202200029096
# 21  FQC-10428            Win 11 Pro OEM OLC OA3  Blanket Order  O202200029095
# 22  KUK-00003  Win 11 Home Advanced OEM OLC OA3  Blanket Order  O202200029094
# 23  KR5-00007  Windows 11 Pro with Downgrade FR  Blanket Order  O202200029093
# 24  KK3-00027                  Win 11 Home Plus  Blanket Order  O202300029194
# 25  KW9-00609           Win 11 Home OEM OLC OA3  Blanket Order  O202300029193
# 26  KK3-00027                  Win 11 Home Plus            NaN            NaN
# 27  KW9-00609           Win 11 Home OEM OLC OA3            NaN            NaN
# 28  FQC-10428            Win 11 Pro OEM OLC OA3            NaN            NaN
# 29  KUK-00003  Win 11 Home Advanced OEM OLC OA3            NaN            NaN
# 0   KK3-00027                  Win 11 Home Plus            NaN            NaN
# 1   KW9-00609           Win 11 Home OEM OLC OA3            NaN            NaN
# 2   FQC-10428            Win 11 Pro OEM OLC OA3            NaN            NaN
# 3   KUK-00003  Win 11 Home Advanced OEM OLC OA3            NaN            NaN
#
#    LG PO Date  Order Qty MS Order No.
# 0  2022-10-13     1000.0   1140097022
# 1  2022-10-10     1200.0   1140096304
# 2  2022-10-10      300.0   1140096914
# 3  2022-10-10       50.0   1140095441
# 4  2022-10-25     1300.0   1140096640
# 5  2022-10-25     2000.0   1140097104
# 6  2022-10-25      700.0   1140097066
# 7  2022-10-25      200.0   1140097093
# 8  2022-10-25      300.0   1140097075
# 9  2022-10-31      500.0   1140097158
# 10 2022-11-09      200.0   1140091178
# 11 2022-12-20      300.0   1140097404
# 12 2022-11-21     1000.0   1140097086
# 13 2022-11-21      600.0   1140096966
# 14 2022-12-05     1600.0   1140092984
# 15 2022-12-05     2300.0   1140091681
# 16 2022-12-05     1200.0   1140095110
# 17 2022-12-05     1200.0   1140094511
# 18 2022-12-05       50.0   1140093984
# 19 2022-12-20      300.0   1140097404
# 20 2022-12-20     5300.0   1140097448
# 21 2022-12-20     1600.0   1140097359
# 22 2022-12-20       60.0   1140097378
# 23 2022-12-20      650.0   1140097413
# 24 2023-01-06     2500.0   1140097466
# 25 2023-01-06      200.0   1140097255
# 26        NaT        NaN          NaN
# 27        NaT        NaN          NaN
# 28        NaT        NaN          NaN
# 29        NaT        NaN          NaN
# 0         NaT        NaN          NaN
# 1         NaT        NaN          NaN
# 2         NaT        NaN          NaN
# 3         NaT        NaN          NaN

# %%
bpo = bpo.reset_index(drop=True)

# %%
with open('D:/Data/DPK blanket PO DB.bin', 'wb') as f:
    pickle.dump(bpo, f)

# %% [markdown]
# ## DPK Blanket PO 발행 완료 후

# %%
with open('D:/Data/DPK blanket PO DB.bin', 'rb') as f:
    bpo = pickle.load(f)

# %%
df1 = pd.read_excel('D:/key order inquiry.xlsx')
df1
# Out:
#      Site     Order Type Key Type     LG\nPO No. LG\nPO Date   MS P/No.  \
# 0  Quanta  Blanket Order      DPK  O202300029240  2023-01-18  KUK-00003
# 1  Quanta  Blanket Order      DPK  O202300029241  2023-01-18  FQC-10428
# 2  Quanta  Blanket Order      DPK  O202300029242  2023-01-18  KW9-00609
# 3  Quanta  Blanket Order      DPK  O202300029243  2023-01-18  KK3-00027
#
#                           Part Name     LG P/No.  Order Qty  Fulfillment\nQty  \
# 0  Win 11 Home Advanced OEM OLC OA3  SAE30762701        140                 0
# 1            Win 11 Pro OEM OLC OA3  SAE30761501       1200                 0
# 2           Win 11 Home OEM OLC OA3  SAE30761301       4200                 0
# 3                  Win 11 Home Plus  SAE30762501       5000                 0
#
#    Gap Qty       Order Status  MS\nOrder No.
# 0      140  OrderAck Response     1140097603
# 1     1200  OrderAck Response     1140087390
# 2     4200  OrderAck Response     1140097612
# 3     5000  OrderAck Response     1140097607

# %%
df1 = df1.rename(columns={'LG\nPO No.':'LG PO No.', 'LG\nPO Date':'LG PO Date', 'MS\nOrder No.':'MS Order No.', 'MS P/No.':'MS P/N', 'LG P/No.':'LG P/N'})
df1
# Out:
#      Site     Order Type Key Type      LG PO No.  LG PO Date     MS P/N  \
# 0  Quanta  Blanket Order      DPK  O202300029240  2023-01-18  KUK-00003
# 1  Quanta  Blanket Order      DPK  O202300029241  2023-01-18  FQC-10428
# 2  Quanta  Blanket Order      DPK  O202300029242  2023-01-18  KW9-00609
# 3  Quanta  Blanket Order      DPK  O202300029243  2023-01-18  KK3-00027
#
#                           Part Name       LG P/N  Order Qty  Fulfillment\nQty  \
# 0  Win 11 Home Advanced OEM OLC OA3  SAE30762701        140                 0
# 1            Win 11 Pro OEM OLC OA3  SAE30761501       1200                 0
# 2           Win 11 Home OEM OLC OA3  SAE30761301       4200                 0
# 3                  Win 11 Home Plus  SAE30762501       5000                 0
#
#    Gap Qty       Order Status  MS Order No.
# 0      140  OrderAck Response    1140097603
# 1     1200  OrderAck Response    1140087390
# 2     4200  OrderAck Response    1140097612
# 3     5000  OrderAck Response    1140097607

# %%
df1 = df1.drop(columns=['Site', 'Key Type', 'Fulfillment\nQty', 'Gap Qty', 'Order Status'])
df1['Order Qty'] = df1['Order Qty'].astype(str).apply(lambda x:int(x.replace(',', '')))
df1['LG PO Date'] = pd.to_datetime(df1['LG PO Date'])
df1
# Out:
#       Order Type      LG PO No. LG PO Date     MS P/N  \
# 0  Blanket Order  O202300029240 2023-01-18  KUK-00003
# 1  Blanket Order  O202300029241 2023-01-18  FQC-10428
# 2  Blanket Order  O202300029242 2023-01-18  KW9-00609
# 3  Blanket Order  O202300029243 2023-01-18  KK3-00027
#
#                           Part Name       LG P/N  Order Qty  MS Order No.
# 0  Win 11 Home Advanced OEM OLC OA3  SAE30762701        140    1140097603
# 1            Win 11 Pro OEM OLC OA3  SAE30761501       1200    1140087390
# 2           Win 11 Home OEM OLC OA3  SAE30761301       4200    1140097612
# 3                  Win 11 Home Plus  SAE30762501       5000    1140097607

# %%
bpo.tail(10)
# Out:
#     Stock  Request Qty   Quanta P/N       LG P/N  Quanta Request Date  \
# 20   2361         5300  AZDPKW11196  SAE30761301  2022-12-20 00:00:00
# 21    947         1600  AZDPKW11197  SAE30761501  2022-12-20 00:00:00
# 22     96           60  AZDPKW11198  SAE30762701  2022-12-20 00:00:00
# 23   1309          650  AZDPKW11297  SAE30761601  2022-12-20 00:00:00
# 24   1217         2500  AZDPKW11161  SAE30762501  2023-01-05 00:00:00
# 25   7127          200  AZDPKW11196  SAE30761301  2023-01-05 00:00:00
# 26   3181         5000  AZDPKW11161  SAE30762501           2023-01-18
# 27   2882         4200  AZDPKW11196  SAE30761301           2023-01-18
# 28   1770         1200  AZDPKW11197  SAE30761501           2023-01-18
# 29     31          140  AZDPKW11198  SAE30762701           2023-01-18
#
#        MS P/N                         Part Name     Order Type      LG PO No.  \
# 20  KW9-00609           Win 11 Home OEM OLC OA3  Blanket Order  O202200029096
# 21  FQC-10428            Win 11 Pro OEM OLC OA3  Blanket Order  O202200029095
# 22  KUK-00003  Win 11 Home Advanced OEM OLC OA3  Blanket Order  O202200029094
# 23  KR5-00007  Windows 11 Pro with Downgrade FR  Blanket Order  O202200029093
# 24  KK3-00027                  Win 11 Home Plus  Blanket Order  O202300029194
# 25  KW9-00609           Win 11 Home OEM OLC OA3  Blanket Order  O202300029193
# 26  KK3-00027                  Win 11 Home Plus            NaN            NaN
# 27  KW9-00609           Win 11 Home OEM OLC OA3            NaN            NaN
# 28  FQC-10428            Win 11 Pro OEM OLC OA3            NaN            NaN
# 29  KUK-00003  Win 11 Home Advanced OEM OLC OA3            NaN            NaN
#
#    LG PO Date  Order Qty MS Order No.
# 20 2022-12-20     5300.0   1140097448
# 21 2022-12-20     1600.0   1140097359
# 22 2022-12-20       60.0   1140097378
# 23 2022-12-20      650.0   1140097413
# 24 2023-01-06     2500.0   1140097466
# 25 2023-01-06      200.0   1140097255
# 26        NaT        NaN          NaN
# 27        NaT        NaN          NaN
# 28        NaT        NaN          NaN
# 29        NaT        NaN          NaN

# %%
for row in df1.iterrows():
    c1 = (bpo['Request Qty'] == row[1]['Order Qty'])
    c2 = (bpo['LG P/N'] == row[1]['LG P/N'])
    bpo.loc[c1 & c2, ['Order Type', 'LG PO No.', 'LG PO Date', 'Order Qty', 'MS Order No.']] = [
        row[1]['Order Type'], row[1]['LG PO No.'], row[1]['LG PO Date'], row[1]['Order Qty'], row[1]['MS Order No.']]

# %%
bpo
# Out:
#     Stock  Request Qty   Quanta P/N       LG P/N  Quanta Request Date  \
# 0     916         1000  AZDPKW10068  SAE30320201  2022-10-10 00:00:00
# 1     820         1200  AZDPKW11196  SAE30761301  2022-10-10 00:00:00
# 2     619          300  AZDPKW11197  SAE30761501  2022-10-10 00:00:00
# 3      45           50  AZDPKW11300  SAE30762601  2022-10-10 00:00:00
# 4    1427         1300  AZDPKW11161  SAE30762501  2022-10-25 00:00:00
# 5    1180         2000  AZDPKW11196  SAE30761301  2022-10-25 00:00:00
# 6     473          700  AZDPKW11197  SAE30761501  2022-10-25 00:00:00
# 7      56          200  AZDPKW11198  SAE30762701  2022-10-25 00:00:00
# 8       0          300  AZDPKW11297  SAE30761601  2022-10-25 00:00:00
# 9    1113          500  AZDPKW11197  SAE30761501  2022-10-31 00:00:00
# 10    784          200  AZDPKW11197  SAE30761501  2022-11-09 00:00:00
# 11   1212          300  AZDPKW11161  SAE30762501  2022-11-21 00:00:00
# 12   1213         1000  AZDPKW11196  SAE30761301  2022-11-21 00:00:00
# 13    392          600  AZDPKW11197  SAE30761501  2022-11-21 00:00:00
# 14    524         1600  AZDPKW11161  SAE30762501  2022-12-05 00:00:00
# 15    976         2300  AZDPKW11196  SAE30761301  2022-12-05 00:00:00
# 16    913         1200  AZDPKW11197  SAE30761501  2022-12-05 00:00:00
# 17    718         1200  AZDPKW11297  SAE30761601  2022-12-05 00:00:00
# 18      0           50  AZDPKW11303  SAE30761801  2022-12-05 00:00:00
# 19   1709          300  AZDPKW11161  SAE30762501  2022-12-20 00:00:00
# 20   2361         5300  AZDPKW11196  SAE30761301  2022-12-20 00:00:00
# 21    947         1600  AZDPKW11197  SAE30761501  2022-12-20 00:00:00
# 22     96           60  AZDPKW11198  SAE30762701  2022-12-20 00:00:00
# 23   1309          650  AZDPKW11297  SAE30761601  2022-12-20 00:00:00
# 24   1217         2500  AZDPKW11161  SAE30762501  2023-01-05 00:00:00
# 25   7127          200  AZDPKW11196  SAE30761301  2023-01-05 00:00:00
# 26   3181         5000  AZDPKW11161  SAE30762501           2023-01-18
# 27   2882         4200  AZDPKW11196  SAE30761301           2023-01-18
# 28   1770         1200  AZDPKW11197  SAE30761501           2023-01-18
# 29     31          140  AZDPKW11198  SAE30762701           2023-01-18
#
#        MS P/N                         Part Name     Order Type      LG PO No.  \
# 0   FQC-08797                    Windows 10 Pro  Blanket Order  O202200028543
# 1   KW9-00609           Win 11 Home OEM OLC OA3  Blanket Order  O202200028505
# 2   FQC-10428            Win 11 Pro OEM OLC OA3  Blanket Order  O202200028504
# 3   NA3-00013               Win 11 Home Plus SL  Blanket Order  O202200028503
# 4   KK3-00027                  Win 11 Home Plus  Blanket Order  O202200028607
# 5   KW9-00609           Win 11 Home OEM OLC OA3  Blanket Order  O202200028606
# 6   FQC-10428            Win 11 Pro OEM OLC OA3  Blanket Order  O202200028605
# 7   KUK-00003  Win 11 Home Advanced OEM OLC OA3  Blanket Order  O202200028604
# 8   KR5-00007  Windows 11 Pro with Downgrade FR  Blanket Order  O202200028603
# 9   FQC-10428            Win 11 Pro OEM OLC OA3  Blanket Order  O202200028623
# 10  FQC-10428            Win 11 Pro OEM OLC OA3  Blanket Order  O202200028733
# 11  KK3-00027                  Win 11 Home Plus  Blanket Order  O202200029097
# 12  KW9-00609           Win 11 Home OEM OLC OA3  Blanket Order  O202200028834
# 13  FQC-10428            Win 11 Pro OEM OLC OA3  Blanket Order  O202200028833
# 14  KK3-00027                  Win 11 Home Plus  Blanket Order  O202200028957
# 15  KW9-00609           Win 11 Home OEM OLC OA3  Blanket Order  O202200028956
# 16  FQC-10428            Win 11 Pro OEM OLC OA3  Blanket Order  O202300029241
# 17  KR5-00007  Windows 11 Pro with Downgrade FR  Blanket Order  O202200028954
# 18  CSQ-00009              Windows 11 Pro Entry  Blanket Order  O202200028953
# 19  KK3-00027                  Win 11 Home Plus  Blanket Order  O202200029097
# 20  KW9-00609           Win 11 Home OEM OLC OA3  Blanket Order  O202200029096
# 21  FQC-10428            Win 11 Pro OEM OLC OA3  Blanket Order  O202200029095
# 22  KUK-00003  Win 11 Home Advanced OEM OLC OA3  Blanket Order  O202200029094
# 23  KR5-00007  Windows 11 Pro with Downgrade FR  Blanket Order  O202200029093
# 24  KK3-00027                  Win 11 Home Plus  Blanket Order  O202300029194
# 25  KW9-00609           Win 11 Home OEM OLC OA3  Blanket Order  O202300029193
# 26  KK3-00027                  Win 11 Home Plus  Blanket Order  O202300029243
# 27  KW9-00609           Win 11 Home OEM OLC OA3  Blanket Order  O202300029242
# 28  FQC-10428            Win 11 Pro OEM OLC OA3  Blanket Order  O202300029241
# 29  KUK-00003  Win 11 Home Advanced OEM OLC OA3  Blanket Order  O202300029240
#
#    LG PO Date  Order Qty MS Order No.
# 0  2022-10-13     1000.0   1140097022
# 1  2022-10-10     1200.0   1140096304
# 2  2022-10-10      300.0   1140096914
# 3  2022-10-10       50.0   1140095441
# 4  2022-10-25     1300.0   1140096640
# 5  2022-10-25     2000.0   1140097104
# 6  2022-10-25      700.0   1140097066
# 7  2022-10-25      200.0   1140097093
# 8  2022-10-25      300.0   1140097075
# 9  2022-10-31      500.0   1140097158
# 10 2022-11-09      200.0   1140091178
# 11 2022-12-20      300.0   1140097404
# 12 2022-11-21     1000.0   1140097086
# 13 2022-11-21      600.0   1140096966
# 14 2022-12-05     1600.0   1140092984
# 15 2022-12-05     2300.0   1140091681
# 16 2023-01-18     1200.0   1140087390
# 17 2022-12-05     1200.0   1140094511
# 18 2022-12-05       50.0   1140093984
# 19 2022-12-20      300.0   1140097404
# 20 2022-12-20     5300.0   1140097448
# 21 2022-12-20     1600.0   1140097359
# 22 2022-12-20       60.0   1140097378
# 23 2022-12-20      650.0   1140097413
# 24 2023-01-06     2500.0   1140097466
# 25 2023-01-06      200.0   1140097255
# 26 2023-01-18     5000.0   1140097607
# 27 2023-01-18     4200.0   1140097612
# 28 2023-01-18     1200.0   1140087390
# 29 2023-01-18      140.0   1140097603

# %%
bpo[bpo['Quanta Request Date'] == bpo['Quanta Request Date'].max()]
# Out:
#     Stock  Request Qty   Quanta P/N       LG P/N Quanta Request Date  \
# 26   3181         5000  AZDPKW11161  SAE30762501          2023-01-18
# 27   2882         4200  AZDPKW11196  SAE30761301          2023-01-18
# 28   1770         1200  AZDPKW11197  SAE30761501          2023-01-18
# 29     31          140  AZDPKW11198  SAE30762701          2023-01-18
#
#        MS P/N                         Part Name     Order Type      LG PO No.  \
# 26  KK3-00027                  Win 11 Home Plus  Blanket Order  O202300029243
# 27  KW9-00609           Win 11 Home OEM OLC OA3  Blanket Order  O202300029242
# 28  FQC-10428            Win 11 Pro OEM OLC OA3  Blanket Order  O202300029241
# 29  KUK-00003  Win 11 Home Advanced OEM OLC OA3  Blanket Order  O202300029240
#
#    LG PO Date  Order Qty MS Order No.
# 26 2023-01-18     5000.0   1140097607
# 27 2023-01-18     4200.0   1140097612
# 28 2023-01-18     1200.0   1140087390
# 29 2023-01-18      140.0   1140097603

# %%
bpo[bpo['Quanta Request Date'] == bpo['Quanta Request Date'].max()].to_clipboard()
# Out:
# C:\Python\Python39\lib\site-packages\numpy\core\_methods.py:40: FutureWarning: Comparison of Timestamp with datetime.date is deprecated in order to match the standard library behavior.  In a future version these will be considered non-comparable.Use 'ts == pd.Timestamp(date)' or 'ts.date() == date' instead.
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# C:\Python\Python39\lib\site-packages\pandas\core\ops\array_ops.py:73: FutureWarning: Comparison of Timestamp with datetime.date is deprecated in order to match the standard library behavior.  In a future version these will be considered non-comparable.Use 'ts == pd.Timestamp(date)' or 'ts.date() == date' instead.
#   result = libops.scalar_compare(x.ravel(), y, op)

# %%
bpo
# Out:
#     Stock  Request Qty   Quanta P/N       LG P/N Quanta Request Date  \
# 0     916         1000  AZDPKW10068  SAE30320201          2022-10-10
# 1     820         1200  AZDPKW11196  SAE30761301          2022-10-10
# 2     619          300  AZDPKW11197  SAE30761501          2022-10-10
# 3      45           50  AZDPKW11300  SAE30762601          2022-10-10
# 4    1427         1300  AZDPKW11161  SAE30762501          2022-10-25
# 5    1180         2000  AZDPKW11196  SAE30761301          2022-10-25
# 6     473          700  AZDPKW11197  SAE30761501          2022-10-25
# 7      56          200  AZDPKW11198  SAE30762701          2022-10-25
# 8       0          300  AZDPKW11297  SAE30761601          2022-10-25
# 9    1113          500  AZDPKW11197  SAE30761501          2022-10-31
# 10    784          200  AZDPKW11197  SAE30761501          2022-11-09
# 11   1212          300  AZDPKW11161  SAE30762501          2022-11-21
# 12   1213         1000  AZDPKW11196  SAE30761301          2022-11-21
# 13    392          600  AZDPKW11197  SAE30761501          2022-11-21
# 14    524         1600  AZDPKW11161  SAE30762501          2022-12-05
# 15    976         2300  AZDPKW11196  SAE30761301          2022-12-05
# 16    913         1200  AZDPKW11197  SAE30761501          2022-12-05
# 17    718         1200  AZDPKW11297  SAE30761601          2022-12-05
# 18      0           50  AZDPKW11303  SAE30761801          2022-12-05
# 19   1709          300  AZDPKW11161  SAE30762501          2022-12-20
# 20   2361         5300  AZDPKW11196  SAE30761301          2022-12-20
# 21    947         1600  AZDPKW11197  SAE30761501          2022-12-20
# 22     96           60  AZDPKW11198  SAE30762701          2022-12-20
# 23   1309          650  AZDPKW11297  SAE30761601          2022-12-20
# 24   1217         2500  AZDPKW11161  SAE30762501          2023-01-05
# 25   7127          200  AZDPKW11196  SAE30761301          2023-01-05
# 26   3181         5000  AZDPKW11161  SAE30762501          2023-01-18
# 27   2882         4200  AZDPKW11196  SAE30761301          2023-01-18
# 28   1770         1200  AZDPKW11197  SAE30761501          2023-01-18
# 29     31          140  AZDPKW11198  SAE30762701          2023-01-18
#
#        MS P/N                         Part Name     Order Type      LG PO No.  \
# 0   FQC-08797                    Windows 10 Pro  Blanket Order  O202200028543
# 1   KW9-00609           Win 11 Home OEM OLC OA3  Blanket Order  O202200028505
# 2   FQC-10428            Win 11 Pro OEM OLC OA3  Blanket Order  O202200028504
# 3   NA3-00013               Win 11 Home Plus SL  Blanket Order  O202200028503
# 4   KK3-00027                  Win 11 Home Plus  Blanket Order  O202200028607
# 5   KW9-00609           Win 11 Home OEM OLC OA3  Blanket Order  O202200028606
# 6   FQC-10428            Win 11 Pro OEM OLC OA3  Blanket Order  O202200028605
# 7   KUK-00003  Win 11 Home Advanced OEM OLC OA3  Blanket Order  O202200028604
# 8   KR5-00007  Windows 11 Pro with Downgrade FR  Blanket Order  O202200028603
# 9   FQC-10428            Win 11 Pro OEM OLC OA3  Blanket Order  O202200028623
# 10  FQC-10428            Win 11 Pro OEM OLC OA3  Blanket Order  O202200028733
# 11  KK3-00027                  Win 11 Home Plus  Blanket Order  O202200029097
# 12  KW9-00609           Win 11 Home OEM OLC OA3  Blanket Order  O202200028834
# 13  FQC-10428            Win 11 Pro OEM OLC OA3  Blanket Order  O202200028833
# 14  KK3-00027                  Win 11 Home Plus  Blanket Order  O202200028957
# 15  KW9-00609           Win 11 Home OEM OLC OA3  Blanket Order  O202200028956
# 16  FQC-10428            Win 11 Pro OEM OLC OA3  Blanket Order  O202300029241
# 17  KR5-00007  Windows 11 Pro with Downgrade FR  Blanket Order  O202200028954
# 18  CSQ-00009              Windows 11 Pro Entry  Blanket Order  O202200028953
# 19  KK3-00027                  Win 11 Home Plus  Blanket Order  O202200029097
# 20  KW9-00609           Win 11 Home OEM OLC OA3  Blanket Order  O202200029096
# 21  FQC-10428            Win 11 Pro OEM OLC OA3  Blanket Order  O202200029095
# 22  KUK-00003  Win 11 Home Advanced OEM OLC OA3  Blanket Order  O202200029094
# 23  KR5-00007  Windows 11 Pro with Downgrade FR  Blanket Order  O202200029093
# 24  KK3-00027                  Win 11 Home Plus  Blanket Order  O202300029194
# 25  KW9-00609           Win 11 Home OEM OLC OA3  Blanket Order  O202300029193
# 26  KK3-00027                  Win 11 Home Plus  Blanket Order  O202300029243
# 27  KW9-00609           Win 11 Home OEM OLC OA3  Blanket Order  O202300029242
# 28  FQC-10428            Win 11 Pro OEM OLC OA3  Blanket Order  O202300029241
# 29  KUK-00003  Win 11 Home Advanced OEM OLC OA3  Blanket Order  O202300029240
#
#    LG PO Date  Order Qty MS Order No.
# 0  2022-10-13     1000.0   1140097022
# 1  2022-10-10     1200.0   1140096304
# 2  2022-10-10      300.0   1140096914
# 3  2022-10-10       50.0   1140095441
# 4  2022-10-25     1300.0   1140096640
# 5  2022-10-25     2000.0   1140097104
# 6  2022-10-25      700.0   1140097066
# 7  2022-10-25      200.0   1140097093
# 8  2022-10-25      300.0   1140097075
# 9  2022-10-31      500.0   1140097158
# 10 2022-11-09      200.0   1140091178
# 11 2022-12-20      300.0   1140097404
# 12 2022-11-21     1000.0   1140097086
# 13 2022-11-21      600.0   1140096966
# 14 2022-12-05     1600.0   1140092984
# 15 2022-12-05     2300.0   1140091681
# 16 2023-01-18     1200.0   1140087390
# 17 2022-12-05     1200.0   1140094511
# 18 2022-12-05       50.0   1140093984
# 19 2022-12-20      300.0   1140097404
# 20 2022-12-20     5300.0   1140097448
# 21 2022-12-20     1600.0   1140097359
# 22 2022-12-20       60.0   1140097378
# 23 2022-12-20      650.0   1140097413
# 24 2023-01-06     2500.0   1140097466
# 25 2023-01-06      200.0   1140097255
# 26 2023-01-18     5000.0   1140097607
# 27 2023-01-18     4200.0   1140097612
# 28 2023-01-18     1200.0   1140087390
# 29 2023-01-18      140.0   1140097603

# %%
bpo['Quanta Request Date'] = pd.to_datetime(bpo['Quanta Request Date'])

# %%
bpo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Stock                30 non-null     int64
#  1   Request Qty          30 non-null     int64
#  2   Quanta P/N           30 non-null     object
#  3   LG P/N               30 non-null     object
#  4   Quanta Request Date  30 non-null     datetime64[ns]
#  5   MS P/N               30 non-null     object
#  6   Part Name            30 non-null     object
#  7   Order Type           30 non-null     object
#  8   LG PO No.            30 non-null     object
#  9   LG PO Date           30 non-null     datetime64[ns]
#  10  Order Qty            30 non-null     float64
#  11  MS Order No.         30 non-null     object
# dtypes: datetime64[ns](2), float64(1), int64(2), object(7)
# memory usage: 2.9+ KB

# %%
with open('D:/Data/DPK blanket PO DB.bin', 'wb') as f:
    pickle.dump(bpo, f)

# %%
with open('D:/Data/DB backup/DPK blanket PO DB.bin', 'wb') as f:
    pickle.dump(bpo, f)

# %% [markdown]
# ## DPK 정보 변경 시 저장

# %%
with open('D:/Data/DB backup/dpk.bin', 'wb') as f:
    pickle.dump(dpk_db, f)
