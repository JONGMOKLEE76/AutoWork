# %%
from tool import *
from openpyxl import load_workbook
from openpyxl.styles import PatternFill
from openpyxl.styles import Alignment
import pyautogui

# %%
# 업무 위치(home, office, laptop) 에 따른 자동화 작업
def open_gscp_window(place):
    if place == 'home': # home에 대한 좌표값 공사 필요
        gscp = pyautogui.locateOnScreen('D:/figure/pyautogui/gscp_home.png', region=(3517, 500, 3771-3517,567-500), confidence=0.9)
        pyautogui.click(gscp, duration=0.2)
        gscp_menu = pyautogui.locateOnScreen('D:/figure/pyautogui/gscp_menu_home.png', region=(2646, 488, 2983-2646, 709-488), confidence=0.9)
        while gscp_menu is None:
                gscp_menu = pyautogui.locateOnScreen('D:/figure/pyautogui/gscp_menu_home.png', region=(2646, 488, 2983-2646, 709-488), confidence=0.9)
    elif place == 'office':
        pyautogui.click(x=3808, y=328, duration=0.2)
        gscp = pyautogui.locateOnScreen('D:/figure/pyautogui/gscp.png', region=(3283, 238, 3615-3283, 331-238), confidence=0.9)
        pyautogui.click(gscp, duration=0.2)
        gscp_menu = pyautogui.locateOnScreen('D:/figure/pyautogui/gscp_menu.png', region=(1375, 385, 2680-1375, 625-385), confidence=0.9)
        while gscp_menu is None:
            gscp_menu = pyautogui.locateOnScreen('D:/figure/pyautogui/gscp_menu.png', region=(1375, 385, 2680-1375, 625-385), confidence=0.9)
    elif place == 'laptop':
        pyautogui.click(x=1890, y=327, duration=0.2)
        gscp = pyautogui.locateOnScreen('D:/figure/pyautogui/gscp.png', region=(1358, 240, 1642-1358, 308-240), confidence=0.9)
        pyautogui.click(gscp, duration=0.2)
        gscp_menu = pyautogui.locateOnScreen('D:/figure/pyautogui/gscp_menu.png', region=(1408, 129, 1679-1408, 298-129), confidence=0.9)
        while gscp_menu is None:
            gscp_menu = pyautogui.locateOnScreen('D:/figure/pyautogui/gscp_menu.png', region=(1408, 129, 1679-1408, 298-129), confidence=0.9)

def select_26w_gscp_shipment_plan(place):
    if place == 'home':
        gscp_analysis_menu = pyautogui.locateOnScreen('D:/figure/pyautogui/gscp_analysis_menu.png', region=(898, 306, 176, 136))
        pyautogui.moveTo(gscp_analysis_menu, duration=0.2)
        pyautogui.sleep(0.2)
        gscp_shipment_plan = pyautogui.locateOnScreen('D:/figure/pyautogui/gscp_shipment_plan.png', region=(881, 325, 172, 107))
        pyautogui.click(gscp_shipment_plan, duration=0.2)
        shipment_plan_tab = pyautogui.locateOnScreen('D:/figure/pyautogui/shipment_plan_tab.png', region=(566, 928, 274, 188))
        while shipment_plan_tab is None:
                shipment_plan_tab = pyautogui.locateOnScreen('D:/figure/pyautogui/shipment_plan_tab.png', region=(566, 928, 274, 188))
    elif place == 'office':
        gscp_analysis_menu = pyautogui.locateOnScreen('D:/figure/pyautogui/gscp_analysis_menu.png', region=(1375, 385, 2241-1375, 683-385))
        pyautogui.moveTo(gscp_analysis_menu, duration=0.2)
        pyautogui.sleep(0.2)
        gscp_shipment_plan = pyautogui.locateOnScreen('D:/figure/pyautogui/gscp_shipment_plan.png', region=(1375, 385, 2241-1375, 683-385))
        pyautogui.click(gscp_shipment_plan, duration=0.2)
        shipment_plan_tab = pyautogui.locateOnScreen('D:/figure/pyautogui/shipment_plan_tab.png', region=(1186, 1050, 1485-1186, 1178-1050), confidence=0.9)
        while shipment_plan_tab is None:
            shipment_plan_tab = pyautogui.locateOnScreen('D:/figure/pyautogui/shipment_plan_tab.png', region=(1186, 1050, 1485-1186, 1178-1050), confidence=0.9)
    elif place == 'laptop':
        gscp_analysis_menu = pyautogui.locateOnScreen('D:/figure/pyautogui/gscp_analysis_menu.png', region=(571, 122, 724-571, 248-122), confidence=0.9)
        pyautogui.moveTo(gscp_analysis_menu, duration=0.2)
        pyautogui.sleep(0.2)
        gscp_shipment_plan = pyautogui.locateOnScreen('D:/figure/pyautogui/gscp_shipment_plan.png', region=(564, 142, 786-564, 497-142), confidence=0.9)
        pyautogui.click(gscp_shipment_plan, duration=0.2)
        shipment_plan_tab = pyautogui.locateOnScreen('D:/figure/pyautogui/shipment_plan_tab.png', region=(243, 786, 498-243, 914-786), confidence=0.9)
        while shipment_plan_tab is None:
                shipment_plan_tab = pyautogui.locateOnScreen('D:/figure/pyautogui/shipment_plan_tab.png', region=(243, 786, 498-243, 914-786), confidence=0.9)

def select_from_site(place):
    if place == 'home':
        pyautogui.click(626, 789, duration=0.2) # CHINA
        pyautogui.scroll(-150)
        pyautogui.click(642, 805, duration=0.2) # OS CHINA
        pyautogui.moveTo(749, 680, duration=0.2)
        pyautogui.dragRel(0, 30, 0.2, button='left')
        pyautogui.click(675, 759, duration=0.2) # AUO
        pyautogui.moveTo(747, 699, duration=0.2)
        pyautogui.dragRel(0, 120, 0.2, button='left')
        pyautogui.click(674, 728, duration=0.2) # Pegatron
        pyautogui.click(675, 773, duration=0.2) # Quanta
        pyautogui.moveTo(749, 786, duration=0.2)
        pyautogui.dragRel(0, 40, 0.2, button='left')
        pyautogui.click(673, 667, duration=0.2) # TCL
        pyautogui.click(675, 758, duration=0.2) # TPV
        pyautogui.click(675, 818, duration=0.2) # WINGTECH
    elif place == 'office':
        pyautogui.click(1264, 868, duration=0.2) # China
        pyautogui.scroll(-150)
        pyautogui.click(1281, 884, duration=0.2) # OS China
        pyautogui.moveTo(1387, 762, duration=0.2)
        pyautogui.dragRel(0, 30, 0.2, button='left')
        pyautogui.click(1315, 837, duration=0.2) # AUO
        pyautogui.click(1315, 898, duration=0.2) # BOEVT
        pyautogui.moveTo(1388, 781, duration=0.2)
        pyautogui.dragRel(0, 120, 0.2, button='left')
        pyautogui.click(1314, 808, duration=0.2) # Pegatron
        pyautogui.click(1314, 853, duration=0.2) # Quanta
        pyautogui.moveTo(1388, 868, duration=0.2)
        pyautogui.dragRel(0, 40, 0.2, button='left')
        pyautogui.click(1314, 747, duration=0.2) # TCL
        pyautogui.click(1314, 837, duration=0.2) # TPV
        pyautogui.click(1315, 896, duration=0.2) # WINGTECH
    elif place == 'laptop':
        pyautogui.click(305, 608, duration=0.2) # China
        pyautogui.scroll(-150)
        pyautogui.click(322, 626, duration=0.2) # OS China
        pyautogui.moveTo(427, 503, duration=0.2)
        pyautogui.dragRel(0, 30, 0.2, button='left')
        pyautogui.click(354, 576, duration=0.2) # AUO
        pyautogui.click(355, 638, duration=0.2) # BOEVT
        pyautogui.moveTo(428, 521, duration=0.2)
        pyautogui.dragRel(0, 120, 0.2, button='left')
        pyautogui.click(355, 547, duration=0.2) # Pegatron
        pyautogui.click(355, 592, duration=0.2) # Quanta
        pyautogui.moveTo(428, 612, duration=0.2)
        pyautogui.dragRel(0, 40, 0.2, button='left')
        pyautogui.click(356, 487, duration=0.2) # TCL
        pyautogui.click(355, 577, duration=0.2) # TPV
        pyautogui.click(354, 637, duration=0.2) # WINGTECH

def select_div(place):
    if place == 'home':
        pyautogui.click(999, 448, duration=0.2) # Division
        pyautogui.keyDown('ctrl')
        pyautogui.click(912, 543, duration=0.2) # MNT
        pyautogui.click(932, 574, duration=0.2) # PC
        pyautogui.keyUp('ctrl')
        pyautogui.click()
        selected_div = pyautogui.locateOnScreen('D:/figure/pyautogui/selected_div.png', region=(750, 347, 394, 207))
        while selected_div is None:
            selected_div = pyautogui.locateOnScreen('D:/figure/pyautogui/selected_div.png', region=(750, 347, 394, 207))
    elif place == 'office':
        pyautogui.click(1638, 525, duration=0.2) # Division
        pyautogui.keyDown('ctrl')
        pyautogui.click(x=1564, y=619, duration=0.2) # MNT 위치
        pyautogui.click(x=1570, y=654, duration=0.2) # PC 위치
        pyautogui.keyUp('ctrl')
        pyautogui.click()
        selected_div = pyautogui.locateOnScreen('D:/figure/pyautogui/selected_div.png', region=(1086, 326, 2651-1086, 935-326))
        while selected_div is None:
            selected_div = pyautogui.locateOnScreen('D:/figure/pyautogui/selected_div.png', region=(1086, 326, 2651-1086, 935-326))
    elif place == 'laptop':
        pyautogui.click(679, 266, duration=0.2) # Division
        pyautogui.keyDown('ctrl')
        pyautogui.click(x=610, y=361, duration=0.2) # MNT 위치
        pyautogui.click(x=614, y=395, duration=0.2) # PC 위치
        pyautogui.keyUp('ctrl')
        pyautogui.click()
        selected_div = pyautogui.locateOnScreen('D:/figure/pyautogui/selected_div.png', region=(519, 238, 704-519, 296-238))
        while selected_div is None:
            selected_div = pyautogui.locateOnScreen('D:/figure/pyautogui/selected_div.png', region=(519, 238, 704-519, 296-238))

def select_from_week(weekname, place):
    if place == 'home':
        pyautogui.click(x=1528, y=448, duration=0.2) # from week 위치
        date1 = datetime.datetime.strptime(weekname[:10], '%Y-%m-%d')
        last_month = move_month(date1.isocalendar().year, get_month_from_date(date1), -1)
        press_num = len(get_weeklist_for_certain_month(*last_month))
        pyautogui.press('down', presses=press_num)
        pyautogui.press('enter')
    elif place == 'office':
        pyautogui.click(x=2165, y=529, duration=0.2) # from week 위치
        date1 = datetime.datetime.strptime(weekname[:10], '%Y-%m-%d')
        last_month = move_month(date1.isocalendar().year, get_month_from_date(date1), -1)
        press_num = len(get_weeklist_for_certain_month(*last_month))
        pyautogui.press('down', presses=press_num)
        pyautogui.press('enter')
    elif place == 'laptop':
        weekname = get_weekname(datetime.date.today())
        pyautogui.click(x=1208, y=268, duration=0.2) # from week 위치
        date1 = datetime.datetime.strptime(weekname[:10], '%Y-%m-%d')
        last_month = move_month(date1.isocalendar().year, get_month_from_date(date1), -1)
        press_num = len(get_weeklist_for_certain_month(*last_month))
        pyautogui.press('down', presses=press_num)
        pyautogui.press('enter')

def search_and_download_excel(week_name, wk_num, place):
    if place == 'home':
        pyautogui.click(x=1912, y=447, interval=0.2) # search 버튼
        pyautogui.sleep(1)
        while not pyautogui.pixelMatchesColor(1457, 471, (255, 255, 255)): # product type 위치
            pyautogui.sleep(1)
        excel_export = pyautogui.locateOnScreen('D:/figure/pyautogui/excel_export.png', region=(1817, 420, 177, 182))
        pyautogui.click(excel_export, duration=0.2)
        pyautogui.click(x=1251, y=715, interval=0.2) # Excel(Html) Export 위치
        pyautogui.sleep(1)
        filename = f'{week_name}_GSCP_raw_data_' + 'ODM_' + datetime.datetime.now().strftime('%Y%m%d_%a_%H%M') + '_'+f'{wk_num}w'
        pyautogui.typewrite(filename, interval=0.1)
        pyautogui.press(['tab', 'down', 'down', 'enter'])
        pyautogui.hotkey('alt', 's')
        while not pyautogui.getActiveWindowTitle().startswith(week_name):
            pyautogui.sleep(1)
        for window in pyautogui.getWindowsWithTitle(filename):
            window.close()
        for window in pyautogui.getWindowsWithTitle('GSCP'):
            if window.title == 'GSCP':
                window.activate()
    elif place == 'office':
        pyautogui.click(x=2540, y=522, interval=0.2) # search 버튼
        pyautogui.sleep(1)
        while not pyautogui.pixelMatchesColor(1564, 554, (255, 255, 255)): # product type 위치
            pyautogui.sleep(1)
        excel_export = pyautogui.locateOnScreen('D:/figure/pyautogui/excel_export.png', region=(2380, 342, 2769-2380, 732-342), confidence=0.9)
        pyautogui.click(excel_export, duration=0.2)
        pyautogui.click(x=1899, y=802, interval=0.2) # Excel(Html) Export 위치
        pyautogui.sleep(1)
        pyautogui.click(2170, 1140, duration=0.2)
        filename = f'{week_name}_GSCP_raw_data_' + 'ODM_' + datetime.datetime.now().strftime('%Y%m%d_%a_%H%M') + '_'+f'{wk_num}w'
        pyautogui.typewrite(filename, interval=0.1)
        pyautogui.press(['tab', 'down', 'down', 'enter'])
        pyautogui.hotkey('alt', 's')
        while not pyautogui.getActiveWindowTitle().startswith(week_name):
            pyautogui.sleep(1)
        for window in pyautogui.getWindowsWithTitle(filename):
            window.close()
        for window in pyautogui.getWindowsWithTitle('GSCP'):
            if window.title == 'GSCP':
                window.activate()
    elif place == 'laptop':
        pyautogui.click(x=1587, y=265, interval=0.2) # search 버튼
        pyautogui.sleep(1)
        while not pyautogui.pixelMatchesColor(1134, 291, (255, 255, 255)): # product type 위치
            pyautogui.sleep(1)
        excel_export = pyautogui.locateOnScreen('D:/figure/pyautogui/excel_export.png', region=(1549, 293, 1645-1549, 352-293))
        pyautogui.click(excel_export, duration=0.2)
        pyautogui.click(x=924, y=534, interval=0.2) # Excel(Html) Export 위치
        pyautogui.sleep(1)
        # pyautogui.click(2170, 1140, duration=0.2)
        filename = f'{week_name}_GSCP_raw_data_' + 'ODM_' + datetime.datetime.now().strftime('%Y%m%d_%a_%H%M') + '_'+f'{wk_num}w'
        pyautogui.typewrite(filename, interval=0.1)
        pyautogui.press(['tab', 'down', 'down', 'enter'])
        pyautogui.hotkey('alt', 's')
        while not pyautogui.getActiveWindowTitle().startswith(week_name):
            pyautogui.sleep(1)
        for window in pyautogui.getWindowsWithTitle(filename):
            window.close()
        for window in pyautogui.getWindowsWithTitle('GSCP'):
            if window.title == 'GSCP':
                window.activate()
        
def set_planweek(place, num):
    if place == 'office':
        pyautogui.click(1863, 525, duration=0.5)
        pyautogui.press('down', num)
        pyautogui.press('enter')
        thisweek = get_weekname(datetime.date.today())
        return get_weekname_from(thisweek, -num)
    elif place == 'home':
        pyautogui.click(1216, 447, duration=0.5)
        pyautogui.press('down', num)
        pyautogui.press('enter')
        thisweek = get_weekname(datetime.date.today())
        return get_weekname_from(thisweek, -num)
    elif place == 'laptop':
        pyautogui.click(902, 269, duration=0.5)
        pyautogui.press('down', num)
        pyautogui.press('enter')
        thisweek = get_weekname(datetime.date.today())
        return get_weekname_from(thisweek, -num)

def select_next_plan_week(place):
    if place == 'office':
        pyautogui.click(1863, 525, duration=0.2)
        pyautogui.press('up')
        pyautogui.press('enter')
    elif place == 'home':
        pyautogui.click(1216, 447, duration=0.2)
        pyautogui.press('up')
        pyautogui.press('enter')
    elif place == 'laptop':
        pyautogui.click(902, 269, duration=0.2)
        pyautogui.press('up')
        pyautogui.press('enter')
    
def select_to_site_all(place):
    if place == 'home':
        pyautogui.click(627, 422, duration=0.2)
        pyautogui.click(626, 573, duration=0.2)
        pyautogui.click(629, 587, duration=0.2)
    elif place == 'office':
        pyautogui.click(1267, 502, duration=0.2)
        pyautogui.click(1266, 651, duration=0.2)
        pyautogui.click(1267, 668, duration=0.2)
    elif place == 'laptop':
        pyautogui.click(307, 242, duration=0.2)
        pyautogui.click(306, 392, duration=0.2)
        pyautogui.click(307, 408, duration=0.2)
    
def select_52w_gscp_shipment_plan(place):
    if place == 'home':
        pyautogui.moveTo(x=1240, y=370, duration=0.2) # GSCP Report 위치
        pyautogui.moveTo(x=1265, y=676, duration=0.5) # GSCP Report 하위 Shipment plan (52w) 위치
        pyautogui.click()
        shipment_plan_tab = pyautogui.locateOnScreen('D:/figure/pyautogui/shipment_plan_52w_tab.png', region=(544, 973, 873-544, 1090-973))
        while shipment_plan_tab is None:
            shipment_plan_tab = pyautogui.locateOnScreen('D:/figure/pyautogui/shipment_plan_52w_tab.png', region=(544, 973, 873-544, 1090-973))
    elif place == 'office':
        pyautogui.moveTo(x=1879, y=447, duration=0.2) # GSCP Report 위치
        pyautogui.moveTo(x=1920, y=752, duration=0.5) # GSCP Report 하위 Shipment plan (52w) 위치
        pyautogui.click()
        while not pyautogui.pixelMatchesColor(1262, 1107, (140, 0, 52)):  # Shipment Plan 클릭 후 왼쪽 하단 Home의 위치
            pyautogui.sleep(1)
    elif place == 'laptop':
        pyautogui.moveTo(x=928, y=186, duration=0.2) # GSCP Report 위치
        pyautogui.moveTo(x=959, y=493, duration=0.5) # GSCP Report 하위 Shipment plan (52w) 위치
        pyautogui.click()
        shipment_plan_tab = pyautogui.locateOnScreen('D:/figure/pyautogui/shipment_plan_52w_tab.png', region=(217, 796, 564-217, 876-796))
        while shipment_plan_tab is None:
            shipment_plan_tab = pyautogui.locateOnScreen('D:/figure/pyautogui/shipment_plan_52w_tab.png', region=(217, 796, 564-217, 876-796))

# %%
# 특정 기준 주차부터 GSCP ODM shipment plan 다운로드 하기(PC, NMT 전체 업체)
wk_num = 26
place = 'office'
go_back = 0 # 금주 기준 몇 주전의 SP부터 다운받을 지 결정
open_gscp_window(place)
if wk_num != 26:
    select_52w_gscp_shipment_plan(place)
    select_to_site_all(place)
else:
    select_26w_gscp_shipment_plan(place)
select_from_site(place)
select_div(place)
p_wk = set_planweek(place, go_back)
while p_wk != get_weekname_from(get_weekname(datetime.date.today()), 1):
    select_from_week(p_wk, place)
    if wk_num != 26:
        print(f'{p_wk}의 SP를 다운로드 합니다.')
        search_and_download_excel(p_wk, 52, place)
    else:
        print(f'{p_wk}의 SP를 다운로드 합니다.')
        search_and_download_excel(p_wk, 26, place)
    p_wk = get_weekname_from(p_wk, 1)
    select_next_plan_week(place)
# Out:
# 2024-03-11(W11)의 SP를 다운로드 합니다.

# %% [markdown]
# # 1. GSCP shipment Plan(엑셀)을 불러와 가공하여 기존 DB에 저장

# %% [markdown]
# ## 1) 추출할 조건의 정의 및 엑셀 파일 선택

# %%
ver = 'Latest'
frozen = 3 # 화요일 확정 전에는 3으로 설정할 것

today = datetime.date.today()
thisweek = get_weekname(today)
filepath = get_filename()
created_at = filepath.split('_')[-4] + filepath.split('_')[-2]
length = filepath.split('_')[-1].split('.')[0]
planweek = filepath.split('/')[-1][:15]
frozen_period = [get_weekname_from(planweek, i) for i in range(frozen+1)] # 확정 구간은 이번주를 포함하여 현재까지 확정되어 있는 주차들을 나타냄. 예를 들어 확정 구간 3주이면 당주 포함 총 4개 주차임
previous_weeklist = get_previous_weeklist(planweek)

created_date = datetime.datetime.strptime(created_at, "%Y%m%d%H%M")
print(f'이번주는 {thisweek} 입니다.')
print(f'선택한 파일의 SP는 {planweek} 기준의 {length} 구간의 {ver} SP 로 추출하겠으며, {datetime.date.strftime(created_date, "%Y-%m-%d %a %H시%M분")}에 업데이트되었습니다.')
print(f'확정구간은 {frozen} 주이며, 확정 구간은 {frozen_period} 입니다.')
print(f'이전달의 주차는 {previous_weeklist} 입니다.')
print(f'선택한 파일의 경로명은 {filepath} 입니다.')
# Out:
# 이번주는 2024-03-11(W11) 입니다.
# 선택한 파일의 SP는 2024-03-11(W11) 기준의 26w 구간의 Latest SP 로 추출하겠으며, 2024-03-11 Mon 09시27분에 업데이트되었습니다.
# 확정구간은 3 주이며, 확정 구간은 ['2024-03-11(W11)', '2024-03-18(W12)', '2024-03-25(W13)', '2024-04-01(W14)'] 입니다.
# 이전달의 주차는 ['2024-01-29(W05)', '2024-02-05(W06)', '2024-02-12(W07)', '2024-02-19(W08)', '2024-02-26(W09)', '2024-03-04(W10)'] 입니다.
# 선택한 파일의 경로명은 D:/Downloads/GSCP Raw/2024-03-11(W11)_GSCP_raw_data_ODM_20240311_Mon_0927_26w.xlsx 입니다.

# %%
with open('D:/Data/ODM GSCP.db', 'rb') as f:
    spdb = pickle.load(f)

# %%
spdb.shape
# Out:
# (480390, 14)

# %%
sp = pd.read_excel(filepath, sheet_name=0, keep_default_na=False, na_values=['', 'nan']) # GSCP로부터 금주 SP를 데이타프레임화trim_column_name(sp)
c1 = sp['From Site'].str.contains('BOEVT')
c2 = sp['Mapping Model.Suffix'].str.match('[2|3][2|4|5|7][G|B|M][A-Z]\d{2}') # ODM 모니터 모델인 것만 찾는 정규표현식
sp = sp[~(c1 & ~c2)].reset_index(drop=True) # BOEVT 모델 중 ODM 모니터가 아닌 것만 제외해서 필터링
trim_column_name(sp)
sp = sp[sp['Category'].str.contains(ver)]
sp['Category'] = ver + length
sp.insert(0, 'Created_at', created_at)
sp.insert(0, 'Planweek', planweek)
sp = sp.set_index(['Planweek', 'Created_at', 'Division', 'From Site', 'Region', 'To Site', 'Biz Type', 'Mapping Model.Suffix', 'Rep PMS', 'Transport Mode', 'Category'])[get_weeklist(sp)].loc[:, previous_weeklist[0]:]
sp.columns.name = 'Week Name'
sp = sp.stack().replace({0:np.nan}).dropna().astype(int).reset_index()
sp.rename(columns={0:'SP'}, inplace=True)
sp.insert(11, 'Frozen', 'N')
sp.loc[sp['Week Name'] <= frozen_period[-1], 'Frozen'] = 'Y'
sp
# Out:
#              Planweek    Created_at Division         From Site Region To Site  \
# 0     2024-03-11(W11)  202403110927      MNT       OS_AUO_CN_P     EU    EEBN
# 1     2024-03-11(W11)  202403110927      MNT       OS_AUO_CN_P     EU    EEBN
# 2     2024-03-11(W11)  202403110927      MNT       OS_AUO_CN_P     EU    EEBN
# 3     2024-03-11(W11)  202403110927      MNT       OS_AUO_CN_P     EU    EEBN
# 4     2024-03-11(W11)  202403110927      MNT       OS_AUO_CN_P     EU    EEBN
# ...               ...           ...      ...               ...    ...     ...
# 2978  2024-03-11(W11)  202403110927       PC  OS_WINGTECH_CN_P  KOREA    EKHQ
# 2979  2024-03-11(W11)  202403110927       PC  OS_WINGTECH_CN_P  KOREA    EKHQ
# 2980  2024-03-11(W11)  202403110927       PC  OS_WINGTECH_CN_P  KOREA    EKHQ
# 2981  2024-03-11(W11)  202403110927       PC  OS_WINGTECH_CN_P  KOREA    EKHQ
# 2982  2024-03-11(W11)  202403110927       PC  OS_WINGTECH_CN_P  KOREA    EKHQ
#
# ...

# %%
spdb = pd.concat([spdb, sp]).reset_index(drop=True)

# %%
spdb.shape
# Out:
# (483373, 14)

# %%
with open('D:/Data/ODM GSCP.db', 'wb') as f:
    pickle.dump(spdb, f)

# %% [markdown]
# ## 변동 SP 내역 확인

# %%
spdb.groupby(['Planweek', 'Category', 'Created_at']).sum('SP').reset_index().iloc[-16:, ] # 선택할 SP의 Version 목록을 출력
# Out:
#             Planweek   Category    Created_at       SP
# 199  2024-02-19(W08)   Final26w  202402201401  1200234
# 200  2024-02-19(W08)   Final52w  202402210937  1441623
# 201  2024-02-19(W08)  Latest26w  202402191522  1200938
# 202  2024-02-19(W08)  Latest26w  202402200910  1208519
# 203  2024-02-19(W08)  Latest26w  202402221037  1200494
# 204  2024-02-26(W09)   Final26w  202402271452  1252087
# 205  2024-02-26(W09)   Final52w  202402281001  1476885
# 206  2024-02-26(W09)  Latest26w  202402261515  1256443
# 207  2024-02-26(W09)  Latest26w  202402270919  1251793
# 208  2024-02-26(W09)  Latest26w  202402290847  1252087
# 209  2024-03-04(W10)   Final26w  202403051512  1166291
# 210  2024-03-04(W10)   Final52w  202403060851  1319123
# 211  2024-03-04(W10)  Latest26w  202403040906  1108174
# 212  2024-03-04(W10)  Latest26w  202403041516  1154181
# 213  2024-03-04(W10)  Latest26w  202403050912  1150811
# 214  2024-03-04(W10)  Latest26w  202403070917  1166621

# %%
i1 = 209 # 방금 다운받은 SP와 비교할 SP Version을 선택
sp1 = spdb.merge(spdb.groupby(['Planweek', 'Category', 'Created_at']).sum('SP').reset_index().iloc[[i1], :3])

# %%
sp_sum = pd.concat([sp, sp1])

# %%
sp_sum['Month'] = sp_sum['Week Name'].apply(lambda x:f'{datetime.date.fromisoformat(x[:10]).isocalendar().year}-{get_month_from_date(datetime.date.fromisoformat(x[:10])):02d}')
months = sorted(sp_sum['Month'].unique())[:5]
sp_sum = sp_sum[sp_sum['Month'].isin(months)]

# %%
gap = sp_sum.groupby(['Planweek', 'Created_at', 'From Site', 'Region', 'Category', 'Month'])['SP'].sum().unstack(['Planweek', 'Category', 'Created_at']).fillna(0).astype(int)
gap['Gap'] = gap[gap.columns[-1]] - gap[gap.columns[0]]
gap_region = gap.unstack('Month').fillna(0).astype(int)

# %%
gap_region
# Out:
# Planweek                2024-03-04(W10)                                  \
# Category                       Final26w
# Created_at                 202403051512
# Month                           2024-02 2024-03 2024-04 2024-05 2024-06
# From Site        Region
# OS_AUO_CN_P      EU               11002    8590   13515   15980    8791
#                  INDIA              572     429       0       0       0
#                  KOREA              858     429     416    2816    1320
#                  MEA               5722    5150       0   10196    2390
#                  NA               11229   26352   14709   20586    7389
#                  SCA                572    5291    4211    5103    1573
#                  SEA               1859    3094    2002    7380    1581
# OS_BOEVT_CN_P    EU                   0       0       0    7296       0
#                  MEA                  0       0       0     768     768
# ...

# %%
# 엑셀파일 여러개를 한꺼번에 DB화 할 때,
ver = 'Final'
frozen = 4
path = 'D:/Downloads/GSCP_ODM_shipment_plan/'

for filename in os.listdir('D:/Downloads/GSCP_ODM_shipment_plan/')[1:]:
    filepath = path + filename
    created_at = filepath.split('_')[-4] + filepath.split('_')[-2]
    length = filepath.split('_')[-1].split('.')[0]
    planweek = filepath.split('/')[-1][:15]
    frozen_period = [get_weekname_from(planweek, i) for i in range(frozen+1)] # 확정 구간은 이번주를 포함하여 현재까지 확정되어 있는 주차들을 나타냄. 예를 들어 확정 구간 3주이면 당주 포함 총 4개 주차임
    previous_weeklist = get_previous_weeklist(planweek)
    created_date = datetime.datetime.strptime(created_at, "%Y%m%d%H%M")
    print(f'선택한 파일의 SP는 {planweek} 기준의 {length} 구간의 {ver} SP 로 추출하겠으며, {datetime.date.strftime(created_date, "%Y-%m-%d %a %H시%M분")}에 업데이트되었습니다.')
    
    with open('D:/Data/ODM GSCP.db', 'rb') as f:
        spdb = pickle.load(f)
    
    sp = pd.read_excel(filepath, sheet_name=0, keep_default_na=False, na_values=['', 'nan']) # GSCP로부터 금주 SP를 데이타프레임화trim_column_name(sp)
    trim_column_name(sp)
    sp = sp[sp['Category'].str.contains(ver)]
    sp['Category'] = ver + length
    sp.insert(0, 'Created_at', created_at)
    sp.insert(0, 'Planweek', planweek)
    sp = sp.set_index(['Planweek', 'Created_at', 'Division', 'From Site', 'To Site', 'Region', 'Biz Type', 'Mapping Model.Suffix', 'Rep PMS', 'Transport Mode', 'Category'])[get_weeklist(sp)].loc[:, previous_weeklist[0]:]
    sp.columns.name = 'Week Name'
    sp = sp.stack().replace({0:np.nan}).dropna().astype(int).reset_index()
    sp.rename(columns={0:'SP'}, inplace=True)
    sp.insert(11, 'Frozen', 'N')
    sp.loc[sp['Week Name'] <= frozen_period[-1], 'Frozen'] = 'Y'
    spdb = pd.concat([spdb, sp]).reset_index(drop=True)
    
    with open('D:/Data/ODM GSCP.db', 'wb') as f:
        pickle.dump(spdb, f)
    with open('D:/Data/DB backup/ODM GSCP.db', 'wb') as f:
        pickle.dump(spdb, f)
# Out:
# 선택한 파일의 SP는 2023-01-02(W01) 기준의 52w 구간의 Final SP 로 추출하겠으며, 2023-09-08 Fri 13시13분에 업데이트되었습니다.
# KeyboardInterrupt
