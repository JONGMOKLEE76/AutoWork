# %%
import pyautogui
from tool import *
import warnings
warnings.filterwarnings('ignore')

# %%
def login_glop(place):
    if place == 'office':
        pyautogui.click(444, 23) # 주소 표시줄 클릭
        pyautogui.sleep(0.3)
        pyautogui.typewrite('glopp.lge.com/index.jsp', interval=0.1)
        pyautogui.press('enter', presses=2, interval=1)
        pyautogui.sleep(1)
        while not pyautogui.pixelMatchesColor(868, 619, (255, 255, 255)):  # GLOPP 최초 로그인 후 초기 정보 로딩까지 대기
            pyautogui.sleep(1)
        pyautogui.moveTo(926, 592, duration=0.3)
    elif place == 'home':
        pyautogui.click(682, 40) # 주소 표시줄 클릭
        pyautogui.sleep(0.3)
        pyautogui.typewrite('glopp.lge.com/index.jsp', interval=0.1)
        pyautogui.press('enter', presses=2, interval=1)
        pyautogui.sleep(1)
        while not pyautogui.pixelMatchesColor(868, 619, (255, 255, 255)):  # GLOPP 최초 로그인 후 초기 정보 로딩까지 대기
            pyautogui.sleep(1)
        pyautogui.moveTo(926, 592, duration=0.3)
    elif place == 'laptop':
        pyautogui.click(333, 27) # 주소 표시줄 클릭
        pyautogui.sleep(0.3)
        pyautogui.typewrite('glopp.lge.com/index.jsp', interval=0.1)
        pyautogui.press('enter', presses=2, interval=1)
        pyautogui.sleep(1)
        while not pyautogui.pixelMatchesColor(183, 973, (255, 255, 255)):  # GLOPP 최초 로그인 후 초기 정보 로딩까지 대기
            pyautogui.sleep(1)
        pyautogui.moveTo(545, 604, duration=0.3)

def select_odm(place, vendor):
    if place == 'office':
        pyautogui.click(1613, 121, duration=0.2) # 업체 선택 dropdown 메뉴 클릭
        pyautogui.moveTo(1710, 160, duration=0.5) # scroll bar를 클릭
        if vendor == 'Pegatron PC':
            pyautogui.dragRel(0, 30, duration=0.3) # scroll bar를 내림
            pyautogui.click(1580, 200, duration=0.2) # Pegatron PC 선택
        elif vendor == 'Pegatron Thin Client':
            pyautogui.dragRel(0, 30, duration=0.3) # scroll bar를 내림
            pyautogui.click(1581, 218, duration=0.2) # Pegatron Thin Client 선택
        elif vendor == 'Quanta':
            pyautogui.dragRel(0, 40, duration=0.3) # scroll bar를 내림
            pyautogui.click(1585, 192, duration=0.2) # Quanta 선택
        elif vendor == 'Wingtech':
            pyautogui.dragRel(0, 60, duration=0.3) # scroll bar를 내림
            pyautogui.click(1591, 227, duration=0.2) # Wingtech 선택
        elif vendor == 'TCL MOKA':
            pyautogui.dragRel(0, 40, duration=0.3) # scroll bar를 내림
            pyautogui.click(1585, 210, duration=0.2) # TCL MOKA 선택
        elif vendor == 'TPV':
            pyautogui.dragRel(0, 45, duration=0.3) # scroll bar를 내림
            pyautogui.click(1596, 207, duration=0.2) # TPV 선택
        elif vendor == 'AUO':
            pyautogui.click(1596, 142, duration=0.2) # AUO 선택
        elif vendor == 'BOEVT':
            pyautogui.click(1576, 161, duration=0.2) # BOEVT 선택

    elif place == 'home':
        pyautogui.click(1450, 177, duration=0.2) # 업체 선택 dropdown 메뉴 클릭
        pyautogui.moveTo(1608, 238, duration=0.2) # scroll bar를 클릭
        if vendor == 'Pegatron PC':
            pyautogui.dragRel(0, 50, duration=0.3) # scroll bar를 내림
            pyautogui.click(1423, 268, duration=0.2) # Pegatron PC 선택
        elif vendor == 'Pegatron Thin Client':
            pyautogui.dragRel(0, 50, duration=0.3) # scroll bar를 내림
            pyautogui.click(1417, 298, duration=0.2) # Pegatron Thin Client 선택
        elif vendor == 'Quanta':
            pyautogui.dragRel(0, 60, duration=0.3) # scroll bar를 내림
            pyautogui.click(1417, 277, duration=0.2) # Quanta 선택
        elif vendor == 'Wingtech':
            pyautogui.dragRel(0, 80, duration=0.3) # scroll bar를 내림
            pyautogui.click(1412, 327, duration=0.2) # Wingtech 선택
        elif vendor == 'TCL MOKA':
            pyautogui.dragRel(0, 60, duration=0.3) # scroll bar를 내림
            pyautogui.click(1412, 309, duration=0.2) # TCL MOKA 선택
        elif vendor == 'TPV':
            pyautogui.dragRel(0, 70, duration=0.3) # scroll bar를 내림
            pyautogui.click(1433, 288, duration=0.2) # TPV 선택
        elif vendor == 'AUO':
            pyautogui.click(1415, 211, duration=0.2) # AUO 선택
        elif vendor == 'BOEVT':
            pyautogui.click(1427, 238, duration=0.2) # BOEVT 선택
            
    elif place == 'laptop':
        pyautogui.click(943, 115, duration=0.2) # 업체 선택 dropdown 메뉴 클릭
        pyautogui.moveTo(944, 159, duration=0.5) # scroll bar를 클릭
        if vendor == 'Pegatron PC':
            pyautogui.dragRel(0, 30, duration=0.3) # scroll bar를 내림
            pyautogui.click(839, 193, duration=0.2) # Pegatron PC 선택
        elif vendor == 'Pegatron Thin Client':
            pyautogui.dragRel(0, 30, duration=0.3) # scroll bar를 내림
            pyautogui.click(833, 212, duration=0.2) # Pegatron Thin Client 선택
        elif vendor == 'Quanta':
            pyautogui.dragRel(0, 40, duration=0.3) # scroll bar를 내림
            pyautogui.click(822, 184, duration=0.2) # Quanta 선택
        elif vendor == 'Wingtech':
            pyautogui.dragRel(0, 60, duration=0.3) # scroll bar를 내림
            pyautogui.click(836, 223, duration=0.2) # Wingtech 선택
        elif vendor == 'TCL MOKA':
            pyautogui.dragRel(0, 40, duration=0.3) # scroll bar를 내림
            pyautogui.click(831, 200, duration=0.2) # TCL MOKA 선택
        elif vendor == 'TPV':
            pyautogui.dragRel(0, 45, duration=0.3) # scroll bar를 내림
            pyautogui.click(835, 195, duration=0.2) # TPV 선택
        elif vendor == 'AUO':
            pyautogui.click(833, 141, duration=0.2) # AUO 선택
        elif vendor == 'BOEVT':
            pyautogui.click(819, 160, duration=0.2) # BOEVT 선택
    pyautogui.sleep(1)
    while not pyautogui.pixelMatchesColor(899, 905, (255, 255, 255)):  # 업체 선택 후 조회될때까지
        pyautogui.sleep(1)

def go_shipping_and_download_excel(place):
    if place == 'office':
        pyautogui.moveTo(613, 82, duration=0.5) # Shipping & Invoicing 선택
        pyautogui.click(610, 121, duration=0.5) # Shipping & Invoicing 하위 메뉴 선택
        pyautogui.sleep(1)
        while not pyautogui.pixelMatchesColor(276, 1407, (255, 255, 255)):  # Shipping & Invoicing 메뉴로 전환될 때까지
            pyautogui.sleep(1)
        pyautogui.click(1884, 186, duration=0.2)
        pyautogui.press('enter')
        print('GLOP에서 파일 다운로드를 시작합니다.')
        while not pyautogui.pixelMatchesColor(1350, 58, (74, 74, 74)):  # 파일 다운로드 완료될 때까지
            pyautogui.sleep(1)
        filepath = 'D:/Downloads/' + [file for file in os.listdir('D:/Downloads/') if 'poshThru' in file][-1]
        print('파일 다운로드 완료!', filepath, end=',')
        return filepath
    elif place == 'home':
        pyautogui.moveTo(898, 125, duration=0.5) # Shipping & Invoicing 선택
        pyautogui.click(893, 181, duration=0.5) # Shipping & Invoicing 하위 메뉴 선택
        pyautogui.sleep(1)
        while not pyautogui.pixelMatchesColor(160, 1940, (255, 255, 255)):  # Shipping & Invoicing 메뉴로 전환될 때까지
            pyautogui.sleep(1)
        pyautogui.click(1863, 272, duration=0.2)
        pyautogui.press('enter')
        print('GLOP에서 파일 다운로드를 시작합니다.')
        while not pyautogui.pixelMatchesColor(1199, 89, (74, 74, 74)):  # 파일 다운로드 완료될 때까지
            pyautogui.sleep(1)
        pyautogui.sleep(1)
        filepath = 'D:/Downloads/' + [file for file in os.listdir('D:/Downloads/') if 'poshThru' in file][-1]
        print('파일 다운로드 완료!', filepath, end=',')
        return filepath
    elif place == 'laptop':
        pyautogui.moveTo(594, 78, duration=0.5) # Shipping & Invoicing 선택
        pyautogui.click(598, 120, duration=0.2) # Shipping & Invoicing 하위 메뉴 선택
        pyautogui.sleep(1)
        while not pyautogui.pixelMatchesColor(204, 900, (255, 255, 255)):  # Shipping & Invoicing 메뉴로 전환될 때까지
            pyautogui.sleep(1)
        pyautogui.moveTo(405, 1026)
        pyautogui.dragRel(270, 0, duration=0.3)
        pyautogui.click(920, 184, duration=0.2)
        pyautogui.press('enter')
        print('GLOP에서 파일 다운로드를 시작합니다.')
        while not pyautogui.pixelMatchesColor(359, 53, (74, 74, 74)):  # 파일 다운로드 완료될 때까지
            pyautogui.sleep(1)
        pyautogui.sleep(2)
        filepath = 'D:/Downloads/' + [file for file in os.listdir('D:/Downloads/') if 'poshThru' in file][-1]
        print('파일 다운로드 완료!', filepath, end=',')
        return filepath

def processing_GLOP_data(filepath, vendor):
    df = pd.read_excel(filepath, sheet_name='DataSet').iloc[:, :48]
    if vendor == 'BOEVT':
        df = df[df['Model'].str.match('[2|3][2|4|5|7][G|B|M][A-Z]\d{2}')] # ODM 모니터 모델만 필터링
    df = df[['Model', 'PO No.', 'Ship To', 'Shipping', 'Cancel', 'PO', 'OQC Report', 'OQC Date', 'OQC Result', 'Ship', 'Issued Date', 'RSD','Ship Date', 'BL No', 'BL Status', 'Method', 'Price Term', 'Unit Price', 'Currency', 'Payment Term', 'PO1 No', 'SO No.', 'Final Destination']]
    df = df[~df['PO No.'].isin(['JGMZ23029072', 'JGMZ23027440', 'JGMZ23025674', 'JGMZ23029071'])] # cancel 되었으나 GLOP에서 'Y'로 되어 있어 강제로 제거 필요
    df.loc[df['PO1 No'].notnull(), 'PO1 No'] = df.loc[df['PO1 No'].notnull(),'PO1 No'].astype('int').astype('str')
    df.loc[df['SO No.'].notnull(), 'SO No.'] = df.loc[df['SO No.'].notnull(), 'SO No.'].astype('int').astype('str')
    df['Ship'].fillna(0, inplace=True)
    df['Ship'] = df['Ship'].astype('int')
    df['Issued Date'] = pd.to_datetime(df['Issued Date'])
    df['RSD'] = pd.to_datetime(df['RSD']) # PO의 RSD를 Datetime 형식으로 변경
    df.rename(columns={'Model':'Mapping Model.Suffix', 'Ship To':'To Site'}, inplace=True)
    div_map = {'Quanta':'PC', 'Pegatron Thin Client':'MNT', 'Pegatron PC':'PC', 'Wingtech':'PC', 'TCL MOKA':'MNT', 'TPV':'MNT', 'AUO':'MNT', 'BOEVT':'MNT'}
    df['Division'] = div_map[vendor]
    df['Updated_at'] = datetime.datetime.now().strftime('%Y%m%d%H%M')
    return df

def update_PO_DB(dataframe, vendor):
    po = dataframe.groupby(['PO No.', 'Cancel', 'Issued Date', 'Mapping Model.Suffix', 'To Site', 'RSD', 'Method', 'Price Term', 'Unit Price', 'Currency', 'Payment Term', 'PO1 No', 'SO No.', 'Final Destination', 'Division', 'Updated_at'], dropna=False)[['PO']].sum().reset_index()
    po['From Site'] = 'OS_' + vendor.upper() + '_CN_P'
    po = po.set_index(['From Site', 'PO No.'])
    with open('D:/Data/ODM PO.db', 'rb') as f:
        po_db = pickle.load(f)
    try:
        if dataframe['Mapping Model.Suffix'].isin(po_db.loc[f'OS_{vendor.upper()}_CN_P']['Mapping Model.Suffix'].unique()).sum() / dataframe.shape[0] > 0.9:
            original_po_db = po_db.copy()
            for i in po.index:
                po_db.loc[i, :] = po.loc[i, :]
            added_po = po_db.drop(index=original_po_db.index)
            with open('D:/Data/ODM PO.db', 'wb') as f:
                pickle.dump(po_db, f)
            with open('D:/Data/DB backup/ODM PO.db', 'wb') as f:
                pickle.dump(po_db, f)
            print(f"{vendor}의 PO DB를 업데이트 하였습니다. PO는 {po_db.shape[0] - original_po_db.shape[0]} 건 추가 되었습니다. ", end='')
            return added_po
        else:
            print(f'업데이트할 데이터가 {vendor.uppper()} 업체의 모델이 아닌 것 같습니다. 시스템을 종료합니다.')
            sys.exit()
    except:
        original_po_db = po_db.copy()
        for i in po.index:
            po_db.loc[i, :] = po.loc[i, :]
        added_po = po_db.drop(index=original_po_db.index)
        with open('D:/Data/ODM PO.db', 'wb') as f:
            pickle.dump(po_db, f)
        with open('D:/Data/DB backup/ODM PO.db', 'wb') as f:
            pickle.dump(po_db, f)
        print(f"{vendor}의 PO DB를 업데이트 하였습니다. PO는 {po_db.shape[0] - original_po_db.shape[0]} 건 추가 되었습니다. ", end='')
        return added_po

def update_SR_DB(dataframe, vendor):
    with open('D:/Data/ODM_SR.db', 'rb') as f:
        SR_db = pickle.load(f)
    original_SR_db = SR_db.copy()
    sr = dataframe[dataframe['Ship Date'].notnull()]
    sr['Ship Date'] = pd.to_datetime(sr['Ship Date'])
    sr['From Site'] = 'OS_' + vendor.upper() + '_CN_P'
    sr = sr.set_index(['From Site', 'PO No.', 'BL No'])
    for i in sr.index:
        SR_db.loc[i, :] = sr.loc[i, :]
    added_sr = SR_db.drop(index=original_SR_db.index)
    with open('D:/Data/ODM PO.db', 'rb') as f:
        po_db = pickle.load(f)
    abnormal_open_po = pd.concat([po_db[po_db['Cancel'] == 'N']['PO'], SR_db.groupby(['From Site', 'PO No.']).sum('Ship')['Ship']], axis=1).fillna(0)
    abnormal_open_po['Open'] = abnormal_open_po['PO'] - abnormal_open_po['Ship']
    abnormal_open_po = abnormal_open_po[abnormal_open_po['Open'] < 0]
    if abnormal_open_po.shape[0] > 0:
        print('WARNING!! SR 업데이트하면서 Open PO 수량이 음수가 되었습니다. 선적 실적이 초과된 것이 없는 지 확인하세요!')
        sys.exit()
    else:
        with open('D:/Data/ODM_SR.db', 'wb') as f:
            pickle.dump(SR_db, f)
        with open('D:/Data/DB backup/ODM_SR.db', 'wb') as f:
            pickle.dump(SR_db, f)
        print(f"{vendor}의 SR DB를 업데이트 하였습니다. 선적은 {SR_db.shape[0] - original_SR_db.shape[0]} 건 추가 되었습니다. ")
        return added_sr

# %%
vendor_list = ['AUO', 'BOEVT', 'Quanta', 'Pegatron Thin Client', 'Pegatron PC', 'Wingtech', 'TCL MOKA', 'TPV']
# vendor_list = ['Wingtech', 'TCL MOKA', 'TPV']
place = 'office'
added_po_total = pd.DataFrame()
added_sr_total = pd.DataFrame()
for num, vendor in enumerate(vendor_list):
    print(f'{num+1}_{vendor}의 GLOP 접속을 시작합니다.')
    login_glop(place)
    select_odm(place, vendor)
    filepath = go_shipping_and_download_excel(place)
    df = processing_GLOP_data(filepath, vendor)
    added_po = update_PO_DB(df, vendor.split(' ')[0])
    added_po_total = pd.concat([added_po_total, added_po])
    added_sr = update_SR_DB(df, vendor.split(' ')[0])
    added_sr_total = pd.concat([added_sr_total, added_sr])
# Out:
# 1_AUO의 GLOP 접속을 시작합니다.
# GLOP에서 파일 다운로드를 시작합니다.
# 파일 다운로드 완료! D:/Downloads/poshThru_20240311080323.xls,AUO의 PO DB를 업데이트 하였습니다. PO는 0 건 추가 되었습니다. AUO의 SR DB를 업데이트 하였습니다. 선적은 5 건 추가 되었습니다.
# 2_BOEVT의 GLOP 접속을 시작합니다.
# GLOP에서 파일 다운로드를 시작합니다.
# 파일 다운로드 완료! D:/Downloads/poshThru_20240311080357.xls,BOEVT의 PO DB를 업데이트 하였습니다. PO는 0 건 추가 되었습니다. BOEVT의 SR DB를 업데이트 하였습니다. 선적은 0 건 추가 되었습니다.
# 3_Quanta의 GLOP 접속을 시작합니다.
# GLOP에서 파일 다운로드를 시작합니다.
# 파일 다운로드 완료! D:/Downloads/poshThru_20240311080432.xls,Quanta의 PO DB를 업데이트 하였습니다. PO는 16 건 추가 되었습니다. Quanta의 SR DB를 업데이트 하였습니다. 선적은 11 건 추가 되었습니다.
# 4_Pegatron Thin Client의 GLOP 접속을 시작합니다.
# GLOP에서 파일 다운로드를 시작합니다.
# 파일 다운로드 완료! D:/Downloads/poshThru_20240311080507.xls,Pegatron의 PO DB를 업데이트 하였습니다. PO는 0 건 추가 되었습니다. Pegatron의 SR DB를 업데이트 하였습니다. 선적은 0 건 추가 되었습니다.
# 5_Pegatron PC의 GLOP 접속을 시작합니다.
# GLOP에서 파일 다운로드를 시작합니다.
# ...

# %%
added_po_total['Week Name'] = added_po_total['RSD'].map(get_weekname) 
added_po_total.pivot_table('PO', index=['From Site', 'To Site', 'Mapping Model.Suffix'], columns='Week Name', aggfunc=sum).fillna('-')
# Out:
# Week Name                                      2024-03-04(W10)  \
# From Site        To Site  Mapping Model.Suffix
# OS_PEGATRON_CN_P EHAP_LGM 16T90SP-G.AP55A                    -
#                           16T90SP-G.AP75A                    -
#                  EHAP_LGS 16T90SP-G.AP55A                    -
#                           16T90SP-G.AP75A                    -
# OS_QUANTA_CN_P   EEPT     14Z90S-G.AA75P                  50.0
#                           14Z90S-G.AA78P                  40.0
#                           15Z90S-G.AA75P                  45.0
#                           15Z90S-G.AA78P                  20.0
#                  EHAP_LGM 14Z90S-G.AP55A                     -
#                           14Z90S-G.AP75A                     -
#                  EHAP_LGS 14Z90S-G.AP55A                     -
#                           14Z90S-G.AP75A                     -
#                  ENUS_V   15Z90S-H.AAB6U1                    -
#
# ...

# %%
added_sr_total['Week Name'] = added_sr_total['Ship Date'].map(get_weekname)
added_sr_total.pivot_table('Ship', index=['From Site', 'To Site', 'Mapping Model.Suffix'], columns=['Week Name', 'Ship Date'], aggfunc=sum).fillna('-')
# Out:
# Week Name                                     2024-03-04(W10)             \
# Ship Date                                          2024-03-07 2024-03-08
# From Site        To Site Mapping Model.Suffix
# OS_AUO_CN_P      EJJP    24GQ50F-B.AJLQ                     -          -
#                          27GQ50F-B.AJLQ                     -          -
#                  ENCI    27GQ50F-B.AUSQ                     -      429.0
#                  ENMS    24GQ50F-B.AWMQ                 572.0          -
#                          27GQ50F-B.AWMQ                 429.0          -
# OS_PEGATRON_CN_P EKHQ    16T90SP-K.AA50K                    -          -
#                          16TG90SP-G.AP56KN                  -          -
#                          16TG90SP-G.AP5HKN                  -          -
#                          16TG90SP-G.AP79KN                  -          -
# OS_QUANTA_CN_P   EJJP    14T90S-M.AA55J                     -          -
# ...

# %% [markdown]
# ## 음수발생시 중복된 B/L 확인

# %%
vendor = 'Wingtech'
df = processing_GLOP_data(get_filename(), vendor)

# %%
with open('D:/Data/ODM_SR.db', 'rb') as f:
    SR_db = pickle.load(f)
with open('D:/Data/ODM PO.db', 'rb') as f:
    po_db = pickle.load(f)

original_SR_db = SR_db.copy()
sr = df[df['Ship Date'].notnull()]
sr['Ship Date'] = pd.to_datetime(sr['Ship Date'])
sr['From Site'] = 'OS_' + vendor.upper() + '_CN_P'
sr = sr.set_index(['From Site', 'PO No.', 'BL No'])
for i in sr.index:
    SR_db.loc[i, :] = sr.loc[i, :]
added_sr = SR_db.drop(index=original_SR_db.index)
    
abnormal_open_po = pd.concat([po_db[po_db['Cancel'] == 'N']['PO'], SR_db.groupby(['From Site', 'PO No.']).sum('Ship')['Ship']], axis=1).fillna(0)
abnormal_open_po['Open'] = abnormal_open_po['PO'] - abnormal_open_po['Ship']
abnormal_open_po = abnormal_open_po[abnormal_open_po['Open'] < 0]
abnormal_open_po
# Out:
#                                   PO   Ship   Open
# From Site        PO No.
# OS_WINGTECH_CN_P ZPCZ24000805  730.0  980.0 -250.0

# %%
SR_db.loc[(f'OS_{vendor.upper()}_CN_P', 'ZPCZ24000805')]
# Out:
#              Mapping Model.Suffix To Site Shipping Cancel     PO OQC Report  \
# BL No
# BAA24030044C       10A30Q-L.AQ14K    EKHQ        Y      N  250.0  No Report
# BAA24030044        10A30Q-L.AQ14K    EKHQ        Y      N  250.0  No Report
# BAA24030046        10A30Q-L.AQ14K    EKHQ        Y      N  480.0  No Report
#
#              OQC Date OQC Result   Ship         Issued Date  ... Method  \
# BL No                                                        ...
# BAA24030044C      NaN  No Report  250.0 2024-01-30 13:53:53  ...    SEA
# BAA24030044       NaN  No Report  250.0 2024-01-30 13:53:53  ...    SEA
# BAA24030046       NaN  No Report  480.0 2024-01-30 13:53:53  ...    SEA
#
#              Price Term Unit Price Currency Payment Term  PO1 No SO No.  \
# BL No
# BAA24030044C        FCA     182.56      USD      Z0090FB     NaN    NaN
# BAA24030044         FCA     182.56      USD      Z0090FB     NaN    NaN
# BAA24030046         FCA     182.56      USD      Z0090FB     NaN    NaN
# ...

# %%
SR_db.shape
# Out:
# (4645, 23)

# %%
idx_value = (f'OS_{vendor.upper()}_CN_P','ZPCZ24000805', 'BAA24030044C')

# %%
SR_db.drop(idx_value).shape
# Out:
# (4644, 23)

# %%
with open('D:/Data/ODM_SR.db', 'wb') as f:
    pickle.dump(SR_db.drop(idx_value), f)

# %%
df = processing_GLOP_data(get_filename(), 'Wingtech')

# %%
df = df[df['Ship Date'].notnull()]

# %%
with open('D:/Data/ODM PO.db', 'rb') as f:
    po_db = pickle.load(f)

# %%
po_db.shape
# Out:
# (3670, 16)

# %%
po_db.loc['OS_QUANTA_CN_P']['Mapping Model.Suffix'].unique()
# Out:
# array(['16T90Q-G.AA75A3', '14T90Q-G.AA79B', '14T90Q-K.AA77A1',
#        '16T90Q-K.AA78A1', '16T90Q-G.AP79G', '16T90Q-G.AA79G',
#        '16T90Q-G.AA76G', '14T90Q-G.AR54C2', '14T90Q-K.AAB7U1',
#        '14T90Q-K.AAB9U1', '16T90Q-K.ADS8U1', '16T90Q-K.ADB8U1',
#        '16T90Q-K.AAC8U1', '16T90Q-K.AAC7U1', '16T90Q-K.AA75A9',
#        '16T90Q-G.AA55A', '16T90Q-G.AA78A', '16T90Q-G.AA78Y',
#        '14T90Q-K.AAB6U1', '16T90Q-K.ADG9U1', '14T90P-K.AAG9U1',
#        '15U70P-J.AA78B', '14T90Q-G.AA75C2', '16T90Q-K.AA78J',
#        '16T90Q-K.AAG6U1', '16T90P-K.APB7U1', '14T90Q-G.AR56C2',
#        '14T90Q-G.AA55Y', '14T90Q-G.AA78B', '14T90Q-K.APG5U1',
#        '16T90Q-K.APB7U1', '16T90Q-G.AA79B', '14T90Q-G.AA75A3',
#        '14T90Q-G.AA55A3', '16T90Q-K.AA75J', '14T90Q-K.AAG9U1',
#        '16T90Q-G.AH75A2', '16T90Q-G.AA75C2', '14T90R-K.ADB9U1',
#        '14T90R-K.AAB6U1', '14T90R-K.AAB8U1', '16T90R-K.AA78A1',
#        '16T90R-G.AA75B', '14T90R-G.AA75B', '14T90R-G.AA74C2',
# ...

# %%
po_db.loc['OS_QUANTA_CN_P']['Updated_at'].dropna().unique()
# Out:
# array(['202312301823', '202401081503', '202401151459', '202401221500',
#        '202401291509', '202402051517', '202402261656', '202402191504',
#        '202402271438', '202402121747', '202402271419'], dtype=object)

# %%
po_db = po_db[po_db['Updated_at'] != '202402271419']

# %%
c1 = po_db['From Site'].str.contains('QUA')
c2 = po_db['Updated_at'] == '202401041017'

# %%
po_db[c1]['Updated_at'].unique()

# %%
po_db = po_db[~(c1 & c2)]

# %%
po_db.head()

# %%
with open('D:/Data/ODM_SR.db', 'rb') as f:
    sr_db = pickle.load(f)

# %%
sr_db.shape
# Out:
# (4513, 23)

# %%
c1 = sr_db['From Site'].str.contains('QUA')
c2 = sr_db['Updated_at'] == '202401041017'

# %%
sr_db[c1]['Updated_at'].unique()

# %%
sr_db = sr_db[~(c1 & c2)]

# %%
sr_db.head(3)

# %%
sr_db = SR_db.set_index(['From Site', 'PO No.', 'BL No'])

# %%
sr_db = sr_db.drop(sr_db[sr_db['Updated_at'] == '202401041010'].index)

# %%
with open('D:/Data/ODM PO.db', 'wb') as f:
    pickle.dump(po_db, f)

# %%
with open('D:/Data/ODM_SR.db', 'wb') as f:
    pickle.dump(SR_db, f)

# %% [markdown]
# # GSCP SP(Latest) Excel Download

# %%
def select_MNT_ODM():
    pyautogui.moveTo(x=1625, y=445, duration=0.5) # GSCP Analysis 위치
    pyautogui.moveTo(x=1611, y=494, duration=0.5) # GSCP Analysis 하위 Shipment plan 위치
    pyautogui.click()
    pyautogui.click(x=1264, y=869, duration=0.5) # China 지역 [+] 위치
    pyautogui.sleep(0.5)
    pyautogui.scroll(-200)
    pyautogui.click(x=1281, y=886, duration=0.5) # OS_china [+] 위치
    pyautogui.sleep(0.5)
    pyautogui.moveTo(x=1387, y=759, duration=0.3) # From Site 스크롤 바 1번째
    pyautogui.dragRel(0, 20, 0.5, button='left')
    pyautogui.click(x=1314, y=867, duration=0.5) # AUO 선택
    pyautogui.moveTo(x=1387, y=777, duration=0.3) # From Site 스크롤 바 2번째
    pyautogui.dragRel(0, 118, 1, button='left')
    pyautogui.click(x=1314, y=807, duration=0.3) # TCL 선택
    pyautogui.click(x=1314, y=896, duration=0.3) # TPV 선택
    pyautogui.click(x=1643, y=526, duration=0.3) # Division 위치
    pyautogui.doubleClick(x=1564, y=619, duration=0.3) # MNT 위치

def Call_GSCP_Window():
    my_system = pyautogui.locateOnScreen('D:/figure/pyautogui/my_system.png', duration=0.2)
    pyautogui.click(my_system)
    pyautogui.moveTo(x=3384, y=499, duration=0.5) # My System 내 위치
    pyautogui.scroll(-585)
    pyautogui.click()
    while not pyautogui.pixelMatchesColor(1253, 433, (177, 0, 66)): # GSCP 타이틀 색상 위치
        pyautogui.sleep(1)
        
def select_PC_ODM():
    pyautogui.moveTo(x=1625, y=445, duration=0.5) # GSCP Analysis 위치
    pyautogui.click(x=1611, y=494, duration=0.5) # GSCP Analysis 하위 Shipment plan 위치
    while not pyautogui.pixelMatchesColor(1262, 1107, (140, 0, 52)):  # Shipment Plan 클릭 후 왼쪽 하단 Home의 위치
        pyautogui.sleep(1)
    pyautogui.moveTo(x=1264, y=869, duration=0.5) # China 지역 [+] 위치
    pyautogui.click()
    pyautogui.scroll(-200) 
    pyautogui.click(x=1281, y=886, duration=0.5) # OS_china [+] 위치
    pyautogui.sleep(0.5)
    pyautogui.moveTo(x=1387, y=759, duration=0.5) # From Site 스크롤 바 1번째
    pyautogui.dragRel(0, 120, 1, button='left')
    pyautogui.click(x=1314, y=805) # Pegatron 위치
    pyautogui.click(x=1313, y=840) # Quanta 위치
    pyautogui.moveTo(x=1386, y=868, duration=0.5) # From Site 스크롤 바 2번째
    pyautogui.dragRel(0, 40, 0.5)
    pyautogui.click(x=1316, y=871) # WingTech 위치
    pyautogui.click(x=1643, y=526, duration=0.5) # Division 위치
    pyautogui.keyDown('ctrl')
    pyautogui.click(x=1564, y=619, duration=0.5) # MNT 위치
    pyautogui.click(x=1570, y=654, duration=0.5) # PC 위치
    pyautogui.keyUp('ctrl')
    pyautogui.click()

def select_from_week(weekname):
    pyautogui.click(x=2165, y=529, duration=0.5) # from week 위치
    date1 = datetime.datetime.strptime(weekname[:10], '%Y-%m-%d')
    last_month = move_month(date1.isocalendar().year, get_month_from_date(date1), -1)
    press_num = len(get_weeklist_for_certain_month(*last_month))
    pyautogui.press('down', presses=press_num)
    pyautogui.press('enter')

# %%
thisweek = get_weekname(datetime.date.today())
select_from_week(thisweek)

# %%
# Shipment Plan 26W download
Call_GSCP_Window()
select_PC_ODM()
thisweek = get_weekname(datetime.date.today())
select_from_week(thisweek)

pyautogui.click(x=2540, y=522, interval=1) # search 버튼
while not pyautogui.pixelMatchesColor(2108, 550, (255, 255, 255)): # product type 위치
    pyautogui.sleep(1)
pyautogui.click(x=2548, y=588, interval=1) # Excel download 위치
pyautogui.click(x=1899, y=802, interval=1) # Excel(Html) Export 위치
pyautogui.sleep(0.5)
pyautogui.click(2608, 704, duration=1)
pyautogui.typewrite('D:/Shipment Plan/GSCP Data', interval=0.2)
pyautogui.press('enter')
pyautogui.click(2312, 1273, duration=0.5)
filename = f'W{datetime.date.today().isocalendar().week}_GSCP_raw_data_' + datetime.datetime.now().strftime('%Y%m%d%H') + '_26w'
pyautogui.typewrite(filename, interval=0.1)
pyautogui.press(['tab', 'down', 'down', 'enter'])
pyautogui.hotkey('alt', 's')

# %%
# 52w shipment Plan download
pyautogui.moveTo(x=3810, y=326, duration=0.5) # My System 메뉴 선택 위치
pyautogui.click()
pyautogui.moveTo(x=3384, y=499, duration=0.5) # My System 내 위치
pyautogui.scroll(-585)
pyautogui.click()
while not pyautogui.pixelMatchesColor(1253, 433, (177, 0, 66)): # GSCP 타이틀 색상 위치
    pyautogui.sleep(1)
pyautogui.sleep(2)
pyautogui.moveTo(x=1879, y=447, duration=1) # GSCP Report 위치
pyautogui.moveTo(x=1920, y=752, duration=0.5) # GSCP Report 하위 Shipment plan (52w) 위치
pyautogui.click()

while not pyautogui.pixelMatchesColor(1262, 1107, (140, 0, 52)):  # Shipment Plan 클릭 후 왼쪽 하단 Home의 위치
    pyautogui.sleep(1)

pyautogui.click(x=1268, y=504, duration=0.8)
pyautogui.click(x=1267, y=666, duration=0.4)
pyautogui.click(x=1267, y=681, duration=0.4)

    
pyautogui.moveTo(x=1264, y=869, duration=0.5) # China 지역 [+] 위치
pyautogui.click()
pyautogui.scroll(-200) 
pyautogui.moveTo(x=1281, y=886, duration=0.5) # OS_china [+] 위치
pyautogui.click()
pyautogui.sleep(0.5)
pyautogui.moveTo(x=1387, y=759, duration=0.5) # From Site 스크롤 바 1번째
pyautogui.dragRel(0, 120, 1, button='left')
pyautogui.click(x=1314, y=805) # Pegatron 위치
pyautogui.click(x=1313, y=840) # Quanta 위치
pyautogui.moveTo(x=1386, y=868, duration=0.5) # From Site 스크롤 바 2번째
pyautogui.dragRel(0, 40, 0.5)
pyautogui.click(x=1316, y=871) # WingTech 위치
pyautogui.click(x=1643, y=526, duration=0.5) # Division 위치
pyautogui.keyDown('ctrl')
pyautogui.click(x=1564, y=619, duration=0.5) # MNT 위치
pyautogui.click(x=1570, y=654, duration=0.5) # PC 위치
pyautogui.keyUp('ctrl')
pyautogui.click()
pyautogui.click(x=2165, y=529, interval=1) # from week 위치
last_month = move_month(datetime.date.today().isocalendar().year, get_month_from_date(datetime.date.today()), -1)
press_num = len(get_weeklist_for_certain_month(*last_month))
pyautogui.press('down', presses=press_num)
pyautogui.press('enter')
pyautogui.click(x=2540, y=522, interval=1) # search 버튼
while not pyautogui.pixelMatchesColor(2108, 550, (255, 255, 255)): # product type 위치
    pyautogui.sleep(1)
pyautogui.click(x=2579, y=584, interval=1) # Excel download 위치
pyautogui.click(x=1899, y=802, interval=1) # Excel(Html) Export 위치
pyautogui.sleep(0.5)
pyautogui.click(2608, 704, duration=1)
pyautogui.typewrite('D:/Shipment Plan/GSCP Data', interval=0.2)
pyautogui.press('enter')
pyautogui.click(2312, 1273, duration=0.5)
filename = f'W{datetime.date.today().isocalendar().week}_GSCP_raw_data_' + datetime.datetime.now().strftime('%Y%m%d%H') + '_52w'
pyautogui.typewrite(filename, interval=0.1)
pyautogui.press(['tab', 'down', 'down', 'enter'])
pyautogui.hotkey('alt', 's')

# %%
for num in range(1, 53):
    filename = f'W{num}'
    pyautogui.moveTo(p1, duration=0.5)
    pyautogui.click()
    pyautogui.write(['up', 'enter'])
    pyautogui.moveTo(p2, duration=0.5)
    pyautogui.click()
    pyautogui.write(['down', 'down', 'down', 'down', 'down', 'enter'])
    pyautogui.moveTo(p3, duration=0.5)
    pyautogui.click()
    pyautogui.sleep(1)
    while not pyautogui.pixelMatchesColor(p4.x, p4.y, (255, 255, 255)):
        pyautogui.sleep(1)
    print('검색 완료')
    pyautogui.moveTo(p5, duration=0.5)
    pyautogui.click()
    pyautogui.moveTo(p6, duration=0.5)
    pyautogui.click()
    pyautogui.sleep(0.5)
    pyautogui.write(f'W{num}')
    pyautogui.write(['enter'])

    while len(pyautogui.getWindowsWithTitle(filename)) == 0:
        print('.', end='')
        pyautogui.sleep(1)
    pyautogui.getWindowsWithTitle(filename)[0].close()
    print(f'{filename} 파일을 닫았습니다.')
    pyautogui.getWindowsWithTitle('GSCP')[0].activate()
